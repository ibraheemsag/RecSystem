# %%
import pandas as pd
import numpy as np
import gc
from tqdm import tqdm

# %%
user_profiles_df = pd.read_pickle("./Datasets/Features3.10/flattened_users_smol.pkl").copy()
movie_features_df = pd.read_pickle("./Datasets/Features3.10/movie_feat_genre_.pkl").copy()
ratings_df = pd.read_pickle("./Datasets/Features3.10/ratings.pkl").copy()

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31972560 entries, 0 to 31972559
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   userId  int64
#  1   rating  float32
#  2   imdbId  int32
# dtypes: float32(1), int32(1), int64(1)
# memory usage: 487.9 MB

# %%
ratings_df["rating"] = ratings_df["rating"].astype("float32")
ratings_df["userId"] = ratings_df["userId"].astype("int32")
ratings_df["imdbId"] = ratings_df["imdbId"].astype("int32")
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31972560 entries, 0 to 31972559
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   userId  int32
#  1   rating  float32
#  2   imdbId  int32
# dtypes: float32(1), int32(2)
# memory usage: 365.9 MB

# %%
movie_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83955 entries, 0 to 83954
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          83955 non-null  int32
#  1   startYear       83954 non-null  float32
#  2   runtimeMinutes  83504 non-null  float32
#  3   genres          83955 non-null  object
#  4   tconst_numeric  83955 non-null  float32
#  5   averageRating   83955 non-null  float32
#  6   numVotes        83955 non-null  float32
#  7   directors       83955 non-null  object
#  8   writers         83955 non-null  object
# dtypes: float32(5), int32(1), object(3)
# memory usage: 3.8+ MB

# %%
user_profiles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200948 entries, 0 to 200947
# Data columns (total 84 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   userId                                     200948 non-null  int32
#  1   total_ratings                              200948 non-null  int32
#  2   rating_avg                                 200948 non-null  float32
#  3   rating_std                                 200948 non-null  float32
#  4   bucket_0_1_movie_ids                       128663 non-null  object
#  5   bucket_0_1_count                           128663 non-null  float32
#  6   bucket_0_1_year_avg                        128663 non-null  float32
#  7   bucket_0_1_runtime_avg                     128663 non-null  float32
#  8   bucket_0_1_rating_avg                      128663 non-null  float32
#  9   bucket_0_1_numvotes_avg                    128663 non-null  float32
#  10  bucket_0_1_top_directors                   128663 non-null  object
#  11  bucket_0_1_top_writers                     128663 non-null  object
#  12  bucket_2_3_movie_ids                       195128 non-null  object
#  13  bucket_2_3_count                           195128 non-null  float32
#  14  bucket_2_3_year_avg                        195128 non-null  float32
#  15  bucket_2_3_runtime_avg                     195128 non-null  float32
#  16  bucket_2_3_rating_avg                      195128 non-null  float32
#  17  bucket_2_3_numvotes_avg                    195128 non-null  float32
#  18  bucket_2_3_top_directors                   195128 non-null  object
#  19  bucket_2_3_top_writers                     195128 non-null  object
#  20  bucket_4_5_movie_ids                       200726 non-null  object
#  21  bucket_4_5_count                           200726 non-null  float32
#  22  bucket_4_5_year_avg                        200726 non-null  float32
#  23  bucket_4_5_runtime_avg                     200726 non-null  float32
#  24  bucket_4_5_rating_avg                      200726 non-null  float32
#  25  bucket_4_5_numvotes_avg                    200726 non-null  float32
#  26  bucket_4_5_top_directors                   200726 non-null  object
#  27  bucket_4_5_top_writers                     200726 non-null  object
#  28  ratio_bucket_0_1_to_bucket_2_3             200948 non-null  float32
#  29  year_avg_diff_bucket_0_1_vs_bucket_2_3     127618 non-null  float32
#  30  runtime_avg_diff_bucket_0_1_vs_bucket_2_3  127618 non-null  float32
#  31  rating_avg_diff_bucket_0_1_vs_bucket_2_3   127618 non-null  float32
#  32  ratio_bucket_0_1_to_bucket_4_5             200948 non-null  float32
#  33  year_avg_diff_bucket_0_1_vs_bucket_4_5     128479 non-null  float32
#  34  runtime_avg_diff_bucket_0_1_vs_bucket_4_5  128479 non-null  float32
#  35  rating_avg_diff_bucket_0_1_vs_bucket_4_5   128479 non-null  float32
#  36  ratio_bucket_2_3_to_bucket_4_5             200948 non-null  float32
#  37  year_avg_diff_bucket_2_3_vs_bucket_4_5     194936 non-null  float32
#  38  runtime_avg_diff_bucket_2_3_vs_bucket_4_5  194936 non-null  float32
#  39  rating_avg_diff_bucket_2_3_vs_bucket_4_5   194936 non-null  float32
#  40  high_vs_low_ratio                          200948 non-null  float32
#  41  rating_proportions_5.0                     200948 non-null  float32
#  42  rating_proportions_4.0                     200948 non-null  float32
#  43  rating_proportions_1.0                     200948 non-null  float32
#  44  rating_proportions_3.0                     200948 non-null  float32
#  45  rating_proportions_2.0                     200948 non-null  float32
#  46  rating_proportions_3.5                     200948 non-null  float32
#  47  rating_proportions_2.5                     200948 non-null  float32
#  48  rating_proportions_4.5                     200948 non-null  float32
#  49  rating_proportions_0.5                     200948 non-null  float32
#  50  rating_proportions_1.5                     200948 non-null  float32
#  51  bucket_0_1_genre_proportions_Drama         200948 non-null  float32
#  52  bucket_0_1_genre_proportions_Comedy        200948 non-null  float32
#  53  bucket_0_1_genre_proportions_Romance       200948 non-null  float32
#  54  bucket_0_1_genre_proportions_Adventure     200948 non-null  float32
#  55  bucket_0_1_genre_proportions_Thriller      200948 non-null  float32
#  56  bucket_0_1_genre_proportions_Fantasy       200948 non-null  float32
#  57  bucket_0_1_genre_proportions_Sci-Fi        200948 non-null  float32
#  58  bucket_0_1_genre_proportions_Action        200948 non-null  float32
#  59  bucket_0_1_genre_proportions_Crime         200948 non-null  float32
#  60  bucket_0_1_genre_proportions_Mystery       200948 non-null  float32
#  61  bucket_2_3_genre_proportions_Drama         200948 non-null  float32
#  62  bucket_2_3_genre_proportions_Comedy        200948 non-null  float32
#  63  bucket_2_3_genre_proportions_Romance       200948 non-null  float32
#  64  bucket_2_3_genre_proportions_Crime         200948 non-null  float32
#  65  bucket_2_3_genre_proportions_Fantasy       200948 non-null  float32
#  66  bucket_2_3_genre_proportions_Thriller      200948 non-null  float32
#  67  bucket_2_3_genre_proportions_Sci-Fi        200948 non-null  float32
#  68  bucket_2_3_genre_proportions_Adventure     200948 non-null  float32
#  69  bucket_2_3_genre_proportions_Action        200948 non-null  float32
#  70  bucket_2_3_genre_proportions_Mystery       200948 non-null  float32
#  71  bucket_4_5_genre_proportions_Drama         200948 non-null  float32
#  72  bucket_4_5_genre_proportions_Comedy        200948 non-null  float32
#  73  bucket_4_5_genre_proportions_Romance       200948 non-null  float32
#  74  bucket_4_5_genre_proportions_Crime         200948 non-null  float32
#  75  bucket_4_5_genre_proportions_Adventure     200948 non-null  float32
#  76  bucket_4_5_genre_proportions_Action        200948 non-null  float32
#  77  bucket_4_5_genre_proportions_Sci-Fi        200948 non-null  float32
#  78  bucket_4_5_genre_proportions_Mystery       200948 non-null  float32
#  79  bucket_4_5_genre_proportions_Thriller      200948 non-null  float32
#  80  bucket_4_5_genre_proportions_Fantasy       200948 non-null  float32
#  81  bucket_0_1_other_genre                     200948 non-null  float32
#  82  bucket_2_3_other_genre                     200948 non-null  float32
#  83  bucket_4_5_other_genre                     200948 non-null  float32
# dtypes: float32(73), int32(2), object(9)
# memory usage: 71.3+ MB

# %% [markdown]
# ### Combine All Features in One Jupyter Notebook to Prevent Memory Crashes

# %%
def create_combined_features_table(ratings_df, user_profiles_df, movie_features_df):
    print("Starting to create combined features table...")

    # Process in chunks
    chunk_size = 1000000  # Adjust based on your available memory
    combined_dfs = []
    
    for chunk_start in tqdm(range(0, len(ratings_df), chunk_size), desc = "chunk processing:" ):
        chunk_end = chunk_start + chunk_size
        ratings_chunk = ratings_df.iloc[chunk_start:chunk_end]
        
        # Merge chunk with user profiles
        combined_chunk = ratings_chunk.merge(user_profiles_df, on="userId", how="left")
        combined_chunk = combined_chunk.merge(movie_features_df, left_on="imdbId", right_on="tconst", how="left")
        
        combined_dfs.append(combined_chunk)
        gc.collect()  # Free memory after each chunk
    
    # Concatenate all chunks
    final_df = pd.concat(combined_dfs, ignore_index=True)
    return final_df

# %%
combined_features = create_combined_features_table(
    ratings_df=ratings_df,
    user_profiles_df=user_profiles_df,
    movie_features_df=movie_features_df
)
# Out:
# Starting to create combined features table...
# chunk processing:: 100%|████████████████████████| 32/32 [00:41<00:00,  1.28s/it]

# %%
pd.to_pickle(combined_features.copy(), "./Datasets/Features3.10/combined_features_xsmall.pkl")

# %%
print(len(combined_features.columns))
print(combined_features.info())
for col in combined_features.columns:
    print(combined_features[col].dtype)
    #print(combined_data[col].isnull().sum())
    #|print(combined_features[col].describe())
# Out:
# 95
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31972560 entries, 0 to 31972559
# Data columns (total 95 columns):
#  #   Column                                     Dtype
# ---  ------                                     -----
#  0   userId                                     int32
#  1   rating                                     float32
#  2   imdbId                                     int32
#  3   total_ratings                              int32
#  4   rating_avg                                 float32
#  5   rating_std                                 float32
#  6   bucket_0_1_movie_ids                       object
#  7   bucket_0_1_count                           float32
#  8   bucket_0_1_year_avg                        float32
#  9   bucket_0_1_runtime_avg                     float32
#  10  bucket_0_1_rating_avg                      float32
#  11  bucket_0_1_numvotes_avg                    float32
#  12  bucket_0_1_top_directors                   object
#  13  bucket_0_1_top_writers                     object
#  14  bucket_2_3_movie_ids                       object
#  15  bucket_2_3_count                           float32
#  16  bucket_2_3_year_avg                        float32
#  17  bucket_2_3_runtime_avg                     float32
#  18  bucket_2_3_rating_avg                      float32
#  19  bucket_2_3_numvotes_avg                    float32
#  20  bucket_2_3_top_directors                   object
#  21  bucket_2_3_top_writers                     object
#  22  bucket_4_5_movie_ids                       object
#  23  bucket_4_5_count                           float32
#  24  bucket_4_5_year_avg                        float32
#  25  bucket_4_5_runtime_avg                     float32
#  26  bucket_4_5_rating_avg                      float32
#  27  bucket_4_5_numvotes_avg                    float32
#  28  bucket_4_5_top_directors                   object
#  29  bucket_4_5_top_writers                     object
#  30  ratio_bucket_0_1_to_bucket_2_3             float32
#  31  year_avg_diff_bucket_0_1_vs_bucket_2_3     float32
#  32  runtime_avg_diff_bucket_0_1_vs_bucket_2_3  float32
#  33  rating_avg_diff_bucket_0_1_vs_bucket_2_3   float32
#  34  ratio_bucket_0_1_to_bucket_4_5             float32
#  35  year_avg_diff_bucket_0_1_vs_bucket_4_5     float32
#  36  runtime_avg_diff_bucket_0_1_vs_bucket_4_5  float32
#  37  rating_avg_diff_bucket_0_1_vs_bucket_4_5   float32
#  38  ratio_bucket_2_3_to_bucket_4_5             float32
#  39  year_avg_diff_bucket_2_3_vs_bucket_4_5     float32
#  40  runtime_avg_diff_bucket_2_3_vs_bucket_4_5  float32
#  41  rating_avg_diff_bucket_2_3_vs_bucket_4_5   float32
#  42  high_vs_low_ratio                          float32
#  43  rating_proportions_5.0                     float32
#  44  rating_proportions_4.0                     float32
#  45  rating_proportions_1.0                     float32
#  46  rating_proportions_3.0                     float32
#  47  rating_proportions_2.0                     float32
#  48  rating_proportions_3.5                     float32
#  49  rating_proportions_2.5                     float32
#  50  rating_proportions_4.5                     float32
#  51  rating_proportions_0.5                     float32
#  52  rating_proportions_1.5                     float32
#  53  bucket_0_1_genre_proportions_Drama         float32
#  54  bucket_0_1_genre_proportions_Comedy        float32
#  55  bucket_0_1_genre_proportions_Romance       float32
#  56  bucket_0_1_genre_proportions_Adventure     float32
#  57  bucket_0_1_genre_proportions_Thriller      float32
#  58  bucket_0_1_genre_proportions_Fantasy       float32
#  59  bucket_0_1_genre_proportions_Sci-Fi        float32
#  60  bucket_0_1_genre_proportions_Action        float32
#  61  bucket_0_1_genre_proportions_Crime         float32
#  62  bucket_0_1_genre_proportions_Mystery       float32
#  63  bucket_2_3_genre_proportions_Drama         float32
#  64  bucket_2_3_genre_proportions_Comedy        float32
#  65  bucket_2_3_genre_proportions_Romance       float32
#  66  bucket_2_3_genre_proportions_Crime         float32
#  67  bucket_2_3_genre_proportions_Fantasy       float32
#  68  bucket_2_3_genre_proportions_Thriller      float32
#  69  bucket_2_3_genre_proportions_Sci-Fi        float32
#  70  bucket_2_3_genre_proportions_Adventure     float32
#  71  bucket_2_3_genre_proportions_Action        float32
#  72  bucket_2_3_genre_proportions_Mystery       float32
#  73  bucket_4_5_genre_proportions_Drama         float32
#  74  bucket_4_5_genre_proportions_Comedy        float32
#  75  bucket_4_5_genre_proportions_Romance       float32
#  76  bucket_4_5_genre_proportions_Crime         float32
#  77  bucket_4_5_genre_proportions_Adventure     float32
#  78  bucket_4_5_genre_proportions_Action        float32
#  79  bucket_4_5_genre_proportions_Sci-Fi        float32
#  80  bucket_4_5_genre_proportions_Mystery       float32
#  81  bucket_4_5_genre_proportions_Thriller      float32
#  82  bucket_4_5_genre_proportions_Fantasy       float32
#  83  bucket_0_1_other_genre                     float32
#  84  bucket_2_3_other_genre                     float32
#  85  bucket_4_5_other_genre                     float32
#  86  tconst                                     int32
#  87  startYear                                  float32
#  88  runtimeMinutes                             float32
#  89  genres                                     object
#  90  tconst_numeric                             float32
#  91  averageRating                              float32
#  92  numVotes                                   float32
#  93  directors                                  object
#  94  writers                                    object
# dtypes: float32(79), int32(4), object(12)
# memory usage: 12.7+ GB
# None
# int32
# float32
# int32
# int32
# float32
# float32
# object
# float32
# float32
# float32
# float32
# float32
# object
# object
# object
# float32
# float32
# float32
# float32
# float32
# object
# object
# object
# float32
# float32
# float32
# float32
# float32
# object
# object
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# int32
# float32
# float32
# object
# float32
# float32
# float32
# object
# object

# %%
### Drop a few columns Train for two days.
### Only shot I have the resources for it
### Remove columns though with already high correlation with each other.
### Perhaps best approach
### Find unnecessary columns
len(combined_features.columns)
# Out:
# 95

# %%
# Calculate deep memory usage of the DataFrame
total_memory_bytes = combined_features.memory_usage(deep=True).sum()

# Convert bytes to gigabytes
total_memory_gb = total_memory_bytes / (1024**3)

print(f"Total memory usage: {total_memory_gb:.4f} GB")
# Out:
# Total memory usage: 51.2854 GB

# %%
print(combined_features["imdbId"].max())
print(combined_features["imdbId"].min())
len(combined_features["imdbId"].unique())
# Out:
# 28995566
# 1
# 83955

# %% [markdown]
# ### Reload Combined_featuers

# %%
combined_features = pd.read_pickle("./Datasets/Features3.10/combined_features.pkl")

# %%
combined_features.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp', 'imdbId', 'total_ratings',
#        'rating_avg', 'rating_std', 'bucket_0_1_movie_ids', 'bucket_0_1_count',
#        ...
#        'tconst', 'primaryTitle', 'isAdult', 'startYear', 'runtimeMinutes',
#        'genres', 'averageRating', 'numVotes', 'directors', 'writers'],
#       dtype='object', length=204)

# %% [markdown]
# ### Remove userid
# We won't need it

# %%
combined_features.drop(["userId"], inplace= True, axis = 1)

# %% [markdown]
# ### Check movieId and Tconst and ImdbID

# %%
combined_features.columns
# Out:
# Index(['movieId', 'rating', 'timestamp', 'imdbId', 'total_ratings',
#        'rating_avg', 'rating_std', 'bucket_0_1_movie_ids', 'bucket_0_1_count',
#        'bucket_0_1_adult_prop',
#        ...
#        'tconst', 'primaryTitle', 'isAdult', 'startYear', 'runtimeMinutes',
#        'genres', 'averageRating', 'numVotes', 'directors', 'writers'],
#       dtype='object', length=203)

# %%
print(combined_features["movieId"])
print(combined_features["imdbId"])
print(combined_features["tconst"])
# Out:
# 0              17
# 1              25
# 2              29
# 3              30
# 4              32
#             ...
# 31972555    79702
# 31972556    79796
# 31972557    80350
# 31972558    80463
# 31972559    87304
# Name: movieId, Length: 31972560, dtype: int64
# 0            114388
# 1            113627
# 2            112682
# 3            115012
# 4            114746
#              ...
# 31972555     446029
# 31972556    1020558
# 31972557    1666186
# 31972558    1285016
# 31972559    1532503
# Name: imdbId, Length: 31972560, dtype: int32
# 0            114388
# 1            113627
# 2            112682
# 3            115012
# 4            114746
#              ...
# 31972555     446029
# 31972556    1020558
# 31972557    1666186
# 31972558    1285016
# 31972559    1532503
# Name: tconst, Length: 31972560, dtype: int32

# %%
combined_features.drop(["movieId", "imdbId"], inplace =True, axis = 1)

# %% [markdown]
# ##### Remove Adult Columns

# %%
adult_columns =combined_features.columns[combined_features.columns.str.contains('adult', case = False)]
adult_columns
# Out:
# Index(['bucket_0_1_adult_prop', 'bucket_2_3_adult_prop',
#        'bucket_4_5_adult_prop', 'overall_adult_prop',
#        'bucket_0_1_genre_proportions_Adult',
#        'bucket_2_3_genre_proportions_Adult',
#        'bucket_4_5_genre_proportions_Adult', 'overall_genre_proportions_Adult',
#        'isAdult'],
#       dtype='object')

# %%
combined_features.drop(adult_columns, inplace = True, axis = 1)
combined_features
# Out:
#           rating   timestamp  total_ratings  rating_avg  rating_std  \
# 0            4.0   944249077            141    3.531915    1.537870
# 1            1.0   944250228            141    3.531915    1.537870
# 2            2.0   943230976            141    3.531915    1.537870
# 3            5.0   944249077            141    3.531915    1.537870
# 4            5.0   943228858            141    3.531915    1.537870
# ...          ...         ...            ...         ...         ...
# 31972555     4.5  1294412589            236    3.595339    1.243887
# 31972556     1.0  1287216292            236    3.595339    1.243887
# 31972557     0.5  1294412671            236    3.595339    1.243887
# 31972558     3.5  1350423800            236    3.595339    1.243887
# 31972559     4.5  1350423523            236    3.595339    1.243887
#
#                                        bucket_0_1_movie_ids  bucket_0_1_count  \
# 0         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 1         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 2         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 3         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 4         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# ...                                                     ...               ...
# 31972555  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972556  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972557  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972558  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972559  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
#
#           bucket_0_1_year_avg  bucket_0_1_year_var  bucket_0_1_runtime_avg  \
# 0                 1989.230769           103.464615              126.730769
# 1                 1989.230769           103.464615              126.730769
# 2                 1989.230769           103.464615              126.730769
# 3                 1989.230769           103.464615              126.730769
# 4                 1989.230769           103.464615              126.730769
# ...                       ...                  ...                     ...
# 31972555          1999.904762           117.890476               96.952381
# 31972556          1999.904762           117.890476               96.952381
# 31972557          1999.904762           117.890476               96.952381
# 31972558          1999.904762           117.890476               96.952381
# 31972559          1999.904762           117.890476               96.952381
#
#           ...  overall_genre_proportions_War   tconst  \
# 0         ...                       0.045455   114388
# 1         ...                       0.045455   113627
# 2         ...                       0.045455   112682
# 3         ...                       0.045455   115012
# 4         ...                       0.045455   114746
# ...       ...                            ...      ...
# 31972555  ...                       0.001642   446029
# 31972556  ...                       0.001642  1020558
# 31972557  ...                       0.001642  1666186
# 31972558  ...                       0.001642  1285016
# 31972559  ...                       0.001642  1532503
#
#                          primaryTitle  startYear  runtimeMinutes  \
# 0               Sense and Sensibility       1995             136
# 1                   Leaving Las Vegas       1995             111
# 2           The City of Lost Children       1995             112
# 3                      Shanghai Triad       1995             108
# 4                          12 Monkeys       1995             129
# ...                               ...        ...             ...
# 31972555  Scott Pilgrim vs. the World       2010             112
# 31972556                    Centurion       2010              97
# 31972557                Vampires Suck       2010              82
# 31972558           The Social Network       2010             120
# 31972559                    Beginners       2010             105
#
#                                genres averageRating numVotes  \
# 0                    [Drama, Romance]           7.7   130226
# 1                    [Drama, Romance]           7.5   139377
# 2         [Adventure, Drama, Fantasy]           7.5    72979
# 3             [Crime, Drama, History]           7.1     6155
# 4         [Mystery, Sci-Fi, Thriller]           8.0   660616
# ...                               ...           ...      ...
# 31972555    [Action, Comedy, Fantasy]           7.5   478444
# 31972556     [Action, Drama, History]           6.3    87775
# 31972557             [Comedy, Horror]           3.4    52852
# 31972558           [Biography, Drama]           7.8   783018
# 31972559     [Comedy, Drama, Romance]           7.2    95719
#
#                        directors                                       writers
# 0                    [nm0000487]                        [nm0000807, nm0000668]
# 1                    [nm0001214]                        [nm3840714, nm0001214]
# 2         [nm0001988, nm0000466]  [nm0012496, nm0000466, nm0001988, nm0491011]
# 3                    [nm0955443]             [nm0270819, nm0910841, nm0944481]
# 4                    [nm0000416]             [nm0003408, nm0672459, nm0672466]
# ...                          ...                                           ...
# 31972555             [nm0942367]             [nm0045209, nm0942367, nm1854069]
# 31972556             [nm0551076]                                   [nm0551076]
# 31972557  [nm0294997, nm0783536]                        [nm0294997, nm0783536]
# 31972558             [nm0000399]                        [nm0815070, nm0583826]
# 31972559             [nm0590122]                                   [nm0590122]
#
# [31972560 rows x 192 columns]

# %% [markdown]
# ### Drop primaryTitle and timestamp

# %%
combined_features.drop(["primaryTitle", "timestamp"], inplace = True, axis = 1)
combined_features
# Out:
#           rating  total_ratings  rating_avg  rating_std  \
# 0            4.0            141    3.531915    1.537870
# 1            1.0            141    3.531915    1.537870
# 2            2.0            141    3.531915    1.537870
# 3            5.0            141    3.531915    1.537870
# 4            5.0            141    3.531915    1.537870
# ...          ...            ...         ...         ...
# 31972555     4.5            236    3.595339    1.243887
# 31972556     1.0            236    3.595339    1.243887
# 31972557     0.5            236    3.595339    1.243887
# 31972558     3.5            236    3.595339    1.243887
# 31972559     4.5            236    3.595339    1.243887
#
#                                        bucket_0_1_movie_ids  bucket_0_1_count  \
# 0         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 1         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 2         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 3         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 4         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# ...                                                     ...               ...
# 31972555  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972556  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972557  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972558  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972559  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
#
#           bucket_0_1_year_avg  bucket_0_1_year_var  bucket_0_1_runtime_avg  \
# 0                 1989.230769           103.464615              126.730769
# 1                 1989.230769           103.464615              126.730769
# 2                 1989.230769           103.464615              126.730769
# 3                 1989.230769           103.464615              126.730769
# 4                 1989.230769           103.464615              126.730769
# ...                       ...                  ...                     ...
# 31972555          1999.904762           117.890476               96.952381
# 31972556          1999.904762           117.890476               96.952381
# 31972557          1999.904762           117.890476               96.952381
# 31972558          1999.904762           117.890476               96.952381
# 31972559          1999.904762           117.890476               96.952381
#
#           bucket_0_1_runtime_var  ...  overall_genre_proportions_Game-Show  \
# 0                     962.524615  ...                                  0.0
# 1                     962.524615  ...                                  0.0
# 2                     962.524615  ...                                  0.0
# 3                     962.524615  ...                                  0.0
# 4                     962.524615  ...                                  0.0
# ...                          ...  ...                                  ...
# 31972555              235.647619  ...                                  0.0
# 31972556              235.647619  ...                                  0.0
# 31972557              235.647619  ...                                  0.0
# 31972558              235.647619  ...                                  0.0
# 31972559              235.647619  ...                                  0.0
#
#           overall_genre_proportions_War   tconst  startYear runtimeMinutes  \
# 0                              0.045455   114388       1995            136
# 1                              0.045455   113627       1995            111
# 2                              0.045455   112682       1995            112
# 3                              0.045455   115012       1995            108
# 4                              0.045455   114746       1995            129
# ...                                 ...      ...        ...            ...
# 31972555                       0.001642   446029       2010            112
# 31972556                       0.001642  1020558       2010             97
# 31972557                       0.001642  1666186       2010             82
# 31972558                       0.001642  1285016       2010            120
# 31972559                       0.001642  1532503       2010            105
#
#                                genres averageRating  numVotes  \
# 0                    [Drama, Romance]           7.7    130226
# 1                    [Drama, Romance]           7.5    139377
# 2         [Adventure, Drama, Fantasy]           7.5     72979
# 3             [Crime, Drama, History]           7.1      6155
# 4         [Mystery, Sci-Fi, Thriller]           8.0    660616
# ...                               ...           ...       ...
# 31972555    [Action, Comedy, Fantasy]           7.5    478444
# 31972556     [Action, Drama, History]           6.3     87775
# 31972557             [Comedy, Horror]           3.4     52852
# 31972558           [Biography, Drama]           7.8    783018
# 31972559     [Comedy, Drama, Romance]           7.2     95719
#
#                        directors                                       writers
# 0                    [nm0000487]                        [nm0000807, nm0000668]
# 1                    [nm0001214]                        [nm3840714, nm0001214]
# 2         [nm0001988, nm0000466]  [nm0012496, nm0000466, nm0001988, nm0491011]
# 3                    [nm0955443]             [nm0270819, nm0910841, nm0944481]
# 4                    [nm0000416]             [nm0003408, nm0672459, nm0672466]
# ...                          ...                                           ...
# 31972555             [nm0942367]             [nm0045209, nm0942367, nm1854069]
# 31972556             [nm0551076]                                   [nm0551076]
# 31972557  [nm0294997, nm0783536]                        [nm0294997, nm0783536]
# 31972558             [nm0000399]                        [nm0815070, nm0583826]
# 31972559             [nm0590122]                                   [nm0590122]
#
# [31972560 rows x 190 columns]

# %% [markdown]
# ### Remove Genres That Appear Significantly Less

# %%
genre_columns = combined_features.columns[combined_features.columns.str.contains("genre")]
genre_columns
# Out:
# Index(['bucket_0_1_genre_proportions_Adventure',
#        'bucket_0_1_genre_proportions_Thriller',
#        'bucket_0_1_genre_proportions_News',
#        'bucket_0_1_genre_proportions_Talk-Show',
#        'bucket_0_1_genre_proportions_Romance',
#        'bucket_0_1_genre_proportions_Western',
#        'bucket_0_1_genre_proportions_Sport',
#        'bucket_0_1_genre_proportions_Fantasy',
#        'bucket_0_1_genre_proportions_Horror',
#        'bucket_0_1_genre_proportions_Crime',
#        ...
#        'overall_genre_proportions_Reality-TV',
#        'overall_genre_proportions_Action',
#        'overall_genre_proportions_Documentary',
#        'overall_genre_proportions_Animation',
#        'overall_genre_proportions_Mystery', 'overall_genre_proportions_Music',
#        'overall_genre_proportions_Musical',
#        'overall_genre_proportions_Game-Show', 'overall_genre_proportions_War',
#        'genres'],
#       dtype='object', length=108)

# %% [markdown]
# #### Create Other Column For Genres

# %%
overall_genre_columns = genre_columns[genre_columns.str.contains("overall")]
overall_genre_columns
# Out:
# Index(['overall_genre_proportions_Adventure',
#        'overall_genre_proportions_Thriller', 'overall_genre_proportions_News',
#        'overall_genre_proportions_Talk-Show',
#        'overall_genre_proportions_Romance',
#        'overall_genre_proportions_Western', 'overall_genre_proportions_Sport',
#        'overall_genre_proportions_Fantasy', 'overall_genre_proportions_Horror',
#        'overall_genre_proportions_Crime', 'overall_genre_proportions_Sci-Fi',
#        'overall_genre_proportions_Biography',
#        'overall_genre_proportions_History', 'overall_genre_proportions_Family',
#        'overall_genre_proportions_Film-Noir',
#        'overall_genre_proportions_Comedy', 'overall_genre_proportions_Drama',
#        'overall_genre_proportions_Short',
#        'overall_genre_proportions_Reality-TV',
#        'overall_genre_proportions_Action',
#        'overall_genre_proportions_Documentary',
#        'overall_genre_proportions_Animation',
#        'overall_genre_proportions_Mystery', 'overall_genre_proportions_Music',
#        'overall_genre_proportions_Musical',
#        'overall_genre_proportions_Game-Show', 'overall_genre_proportions_War'],
#       dtype='object')

# %% [markdown]
# ##### Find top 15 columns with highest average

# %%
# Get means of all columns and sort in descending order
means = combined_features[overall_genre_columns].mean().sort_values(ascending=False)

# Display top N means (e.g., top 10)
print(means.head(15))
# Out:
# overall_genre_proportions_Drama        0.192170
# overall_genre_proportions_Comedy       0.135380
# overall_genre_proportions_Action       0.107409
# overall_genre_proportions_Adventure    0.106616
# overall_genre_proportions_Crime        0.071704
# overall_genre_proportions_Thriller     0.056908
# overall_genre_proportions_Romance      0.053774
# overall_genre_proportions_Sci-Fi       0.050607
# overall_genre_proportions_Fantasy      0.039076
# overall_genre_proportions_Mystery      0.036953
# overall_genre_proportions_Horror       0.028189
# overall_genre_proportions_Animation    0.025958
# overall_genre_proportions_Family       0.023122
# overall_genre_proportions_Biography    0.022253
# overall_genre_proportions_War          0.009906
# dtype: float64

# %%
top15 = means.head(15).keys()
top15
# Out:
# Index(['overall_genre_proportions_Drama', 'overall_genre_proportions_Comedy',
#        'overall_genre_proportions_Action',
#        'overall_genre_proportions_Adventure',
#        'overall_genre_proportions_Crime', 'overall_genre_proportions_Thriller',
#        'overall_genre_proportions_Romance', 'overall_genre_proportions_Sci-Fi',
#        'overall_genre_proportions_Fantasy',
#        'overall_genre_proportions_Mystery', 'overall_genre_proportions_Horror',
#        'overall_genre_proportions_Animation',
#        'overall_genre_proportions_Family',
#        'overall_genre_proportions_Biography', 'overall_genre_proportions_War'],
#       dtype='object')

# %%
top15genre = top15.str.replace("overall_genre_proportions_", "")
top15genre
# Out:
# Index(['Drama', 'Comedy', 'Action', 'Adventure', 'Crime', 'Thriller',
#        'Romance', 'Sci-Fi', 'Fantasy', 'Mystery', 'Horror', 'Animation',
#        'Family', 'Biography', 'War'],
#       dtype='object')

# %%
bucket_prefixes = ['bucket_0_1', 'bucket_2_3', 'bucket_4_5', 'overall']
allothers = []  # To collect columns that should be dropped

for bucket in bucket_prefixes:
    other = []
    curr_genres = [col for col in genre_columns if col.startswith(bucket)]
    for curr_genre in curr_genres:
        if curr_genre.split("_")[-1] not in top15genre:
            other.append(curr_genre)
    combined_features[bucket + "_genre_proportions_Other"] = combined_features[other].sum(axis=1)
    allothers.extend(other)

print(combined_features.shape)  # Check the shape of the updated dataframe
print(f"Number of columns that can be dropped: {len(allothers)}")

# Now you can drop these columns if needed:
# Out:
# (31972560, 194)
# Number of columns that can be dropped: 47

# %%
combined_features.drop(columns=allothers, inplace=True)

# %%
combined_features.shape
# Out:
# (31972560, 147)

# %%
for col in combined_features.columns:
    print(col)
    print(combined_features[col].dtype)
    #print(combined_data[col].isnull().sum())
    #|print(combined_features[col].describe())
# Out:
# rating
# float64
# total_ratings
# int64
# rating_avg
# float64
# rating_std
# float64
# bucket_0_1_movie_ids
# object
# bucket_0_1_count
# float64
# bucket_0_1_year_avg
# float64
# bucket_0_1_year_var
# float64
# bucket_0_1_runtime_avg
# float64
# bucket_0_1_runtime_var
# float64
# bucket_0_1_rating_avg
# float64
# bucket_0_1_rating_var
# float64
# bucket_0_1_numvotes_avg
# float64
# bucket_0_1_numvotes_var
# float64
# bucket_0_1_top_directors
# object
# bucket_0_1_top_writers
# object
# bucket_2_3_movie_ids
# object
# bucket_2_3_count
# float64
# bucket_2_3_year_avg
# float64
# bucket_2_3_year_var
# float64
# bucket_2_3_runtime_avg
# float64
# bucket_2_3_runtime_var
# float64
# bucket_2_3_rating_avg
# float64
# bucket_2_3_rating_var
# float64
# bucket_2_3_numvotes_avg
# float64
# bucket_2_3_numvotes_var
# float64
# bucket_2_3_top_directors
# object
# bucket_2_3_top_writers
# object
# bucket_4_5_movie_ids
# object
# bucket_4_5_count
# float64
# bucket_4_5_year_avg
# float64
# bucket_4_5_year_var
# float64
# bucket_4_5_runtime_avg
# float64
# bucket_4_5_runtime_var
# float64
# bucket_4_5_rating_avg
# float64
# bucket_4_5_rating_var
# float64
# bucket_4_5_numvotes_avg
# float64
# bucket_4_5_numvotes_var
# float64
# bucket_4_5_top_directors
# object
# bucket_4_5_top_writers
# object
# ratio_bucket_0_1_to_bucket_2_3
# float64
# year_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# runtime_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# rating_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# ratio_bucket_0_1_to_bucket_4_5
# float64
# year_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# runtime_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# rating_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# ratio_bucket_2_3_to_bucket_4_5
# float64
# year_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# runtime_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# rating_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# high_vs_low_ratio
# float64
# overall_movie_ids
# object
# overall_count
# int64
# overall_year_avg
# float64
# overall_year_var
# float64
# overall_runtime_avg
# float64
# overall_runtime_var
# float64
# overall_rating_avg
# float64
# overall_rating_var
# float64
# overall_numvotes_avg
# float64
# overall_numvotes_var
# float64
# overall_top_directors
# object
# overall_top_writers
# object
# rating_proportions_0.5
# float64
# rating_proportions_1.0
# float64
# rating_proportions_2.0
# float64
# rating_proportions_3.0
# float64
# rating_proportions_4.0
# float64
# rating_proportions_5.0
# float64
# rating_proportions_3.5
# float64
# rating_proportions_2.5
# float64
# rating_proportions_4.5
# float64
# rating_proportions_1.5
# float64
# bucket_0_1_genre_proportions_Family
# float64
# bucket_0_1_genre_proportions_Animation
# float64
# bucket_0_1_genre_proportions_Sci-Fi
# float64
# bucket_0_1_genre_proportions_Thriller
# float64
# bucket_0_1_genre_proportions_Comedy
# float64
# bucket_0_1_genre_proportions_Biography
# float64
# bucket_0_1_genre_proportions_Adventure
# float64
# bucket_0_1_genre_proportions_Action
# float64
# bucket_0_1_genre_proportions_Romance
# float64
# bucket_0_1_genre_proportions_Horror
# float64
# bucket_0_1_genre_proportions_Drama
# float64
# bucket_0_1_genre_proportions_Fantasy
# float64
# bucket_0_1_genre_proportions_Mystery
# float64
# bucket_0_1_genre_proportions_Crime
# float64
# bucket_0_1_genre_proportions_War
# float64
# bucket_2_3_genre_proportions_Family
# float64
# bucket_2_3_genre_proportions_Animation
# float64
# bucket_2_3_genre_proportions_Sci-Fi
# float64
# bucket_2_3_genre_proportions_Thriller
# float64
# bucket_2_3_genre_proportions_Comedy
# float64
# bucket_2_3_genre_proportions_Biography
# float64
# bucket_2_3_genre_proportions_Adventure
# float64
# bucket_2_3_genre_proportions_Action
# float64
# bucket_2_3_genre_proportions_Romance
# float64
# bucket_2_3_genre_proportions_Horror
# float64
# bucket_2_3_genre_proportions_Drama
# float64
# bucket_2_3_genre_proportions_Fantasy
# float64
# bucket_2_3_genre_proportions_Mystery
# float64
# bucket_2_3_genre_proportions_Crime
# float64
# bucket_2_3_genre_proportions_War
# float64
# bucket_4_5_genre_proportions_Family
# float64
# bucket_4_5_genre_proportions_Animation
# float64
# bucket_4_5_genre_proportions_Sci-Fi
# float64
# bucket_4_5_genre_proportions_Thriller
# float64
# bucket_4_5_genre_proportions_Comedy
# float64
# bucket_4_5_genre_proportions_Biography
# float64
# bucket_4_5_genre_proportions_Adventure
# float64
# bucket_4_5_genre_proportions_Action
# float64
# bucket_4_5_genre_proportions_Romance
# float64
# bucket_4_5_genre_proportions_Horror
# float64
# bucket_4_5_genre_proportions_Drama
# float64
# bucket_4_5_genre_proportions_Fantasy
# float64
# bucket_4_5_genre_proportions_Mystery
# float64
# bucket_4_5_genre_proportions_Crime
# float64
# bucket_4_5_genre_proportions_War
# float64
# overall_genre_proportions_Family
# float64
# overall_genre_proportions_Animation
# float64
# overall_genre_proportions_Sci-Fi
# float64
# overall_genre_proportions_Thriller
# float64
# overall_genre_proportions_Comedy
# float64
# overall_genre_proportions_Biography
# float64
# overall_genre_proportions_Adventure
# float64
# overall_genre_proportions_Action
# float64
# overall_genre_proportions_Romance
# float64
# overall_genre_proportions_Horror
# float64
# overall_genre_proportions_Drama
# float64
# overall_genre_proportions_Fantasy
# float64
# overall_genre_proportions_Mystery
# float64
# overall_genre_proportions_Crime
# float64
# overall_genre_proportions_War
# float64
# tconst
# int64
# startYear
# object
# runtimeMinutes
# object
# genres
# object
# averageRating
# float64
# numVotes
# int64
# directors
# object
# writers
# object
# bucket_0_1_genre_proportions_Other
# float64
# bucket_2_3_genre_proportions_Other
# float64
# bucket_4_5_genre_proportions_Other
# float64
# overall_genre_proportions_Other
# float64

# %%
combined_features["tconst_str"] = "tt" + combined_features["tconst"].astype(str)
combined_features["tconst_str"]
# Out:
# 0            tt114388
# 1            tt113627
# 2            tt112682
# 3            tt115012
# 4            tt114746
#               ...
# 31972555     tt446029
# 31972556    tt1020558
# 31972557    tt1666186
# 31972558    tt1285016
# 31972559    tt1532503
# Name: tconst_str, Length: 31972560, dtype: object

# %%
combined_features.drop(columns=["tconst"], inplace=True)

# %%
combined_features.to_pickle("./Datasets/Features3.10/combined_features2.0med.pkl")

# %%
combined_features.columns
# Out:
# Index(['rating', 'total_ratings', 'rating_avg', 'rating_std',
#        'bucket_0_1_movie_ids', 'bucket_0_1_count', 'bucket_0_1_year_avg',
#        'bucket_0_1_year_var', 'bucket_0_1_runtime_avg',
#        'bucket_0_1_runtime_var',
#        ...
#        'genres', 'averageRating', 'numVotes', 'directors', 'writers',
#        'bucket_0_1_genre_proportions_Other',
#        'bucket_2_3_genre_proportions_Other',
#        'bucket_4_5_genre_proportions_Other', 'overall_genre_proportions_Other',
#        'tconst_str'],
#       dtype='object', length=147)

# %%
for column in combined_features.columns:
    print(column)
    print(combined_features[column][0])
    print(combined_features[column].dtype)
# Out:
# rating
# 4.0
# float64
# total_ratings
# 141
# int64
# rating_avg
# 3.5319148936170213
# float64
# rating_std
# 1.5378704733185982
# float64
# bucket_0_1_movie_ids
# ['tt0056172', 'tt0059113', 'tt0071853', 'tt0079367', 'tt0079470', 'tt0088933', 'tt0090830', 'tt0092699', 'tt0093389', 'tt0093779', 'tt0095953', 'tt0097441', 'tt0104257', 'tt0109045', 'tt0112740', 'tt0112818', 'tt0113627', 'tt0117318', 'tt0117631', 'tt0118799', 'tt0119822', 'tt0120663', 'tt0120716', 'tt0128853', 'tt0163187', 'tt0166896']
# object
# bucket_0_1_count
# 26.0
# float64
# bucket_0_1_year_avg
# 1989.2307692307693
# float64
# bucket_0_1_year_var
# 103.46461538461534
# float64
# bucket_0_1_runtime_avg
# 126.73076923076923
# float64
# bucket_0_1_runtime_var
# 962.5246153846153
# float64
# bucket_0_1_rating_avg
# 7.511538461538461
# float64
# bucket_0_1_rating_var
# 0.39786153846153843
# float64
# bucket_0_1_numvotes_avg
# 220789.07692307694
# float64
# bucket_0_1_numvotes_var
# 41145849087.273834
# float64
# bucket_0_1_top_directors
# ['nm0000180', 'nm0001402', 'nm0000985']
# object
# bucket_0_1_top_writers
# ['nm0004122', 'nm0001385', 'nm0001589']
# object
# bucket_2_3_movie_ids
# ['tt0034583', 'tt0042546', 'tt0045793', 'tt0051459', 'tt0061512', 'tt0064115', 'tt0085244', 'tt0086190', 'tt0087995', 'tt0088846', 'tt0091867', 'tt0093191', 'tt0095765', 'tt0098213', 'tt0102926', 'tt0108052', 'tt0109445', 'tt0109830', 'tt0112431', 'tt0112573', 'tt0112682', 'tt0112769', 'tt0116282', 'tt0116353', 'tt0117802', 'tt0119942', 'tt0120815', 'tt0122541', 'tt0123755', 'tt0129387', 'tt0151804', 'tt0165859']
# object
# bucket_2_3_count
# 32.0
# float64
# bucket_2_3_year_avg
# 1985.96875
# float64
# bucket_2_3_year_var
# 247.70866935483872
# float64
# bucket_2_3_runtime_avg
# 119.0
# float64
# bucket_2_3_runtime_var
# 772.5806451612904
# float64
# bucket_2_3_rating_avg
# 7.675
# float64
# bucket_2_3_rating_var
# 0.4838709677419356
# float64
# bucket_2_3_numvotes_avg
# 422799.25
# float64
# bucket_2_3_numvotes_var
# 362854551739.5484
# float64
# bucket_2_3_top_directors
# ['nm0000229', 'nm0002031', 'nm0371852']
# object
# bucket_2_3_top_writers
# ['nm0001410', 'nm0001054', 'nm0001053']
# object
# bucket_4_5_movie_ids
# ['tt0032143', 'tt0033467', 'tt0036868', 'tt0042192', 'tt0046250', 'tt0047437', 'tt0048728', 'tt0050083', 'tt0050825', 'tt0053125', 'tt0053604', 'tt0055630', 'tt0057115', 'tt0061578', 'tt0061722', 'tt0063442', 'tt0064665', 'tt0065377', 'tt0066206', 'tt0070735', 'tt0071562', 'tt0075314', 'tt0076759', 'tt0077416', 'tt0078346', 'tt0078788', 'tt0080678', 'tt0080684', 'tt0081398', 'tt0082096', 'tt0083658', 'tt0084589', 'tt0086879', 'tt0088258', 'tt0088763', 'tt0088847', 'tt0089881', 'tt0089886', 'tt0090605', 'tt0091042', 'tt0091763', 'tt0092005', 'tt0093870', 'tt0094737', 'tt0094947', 'tt0095593', 'tt0097123', 'tt0099685', 'tt0103130', 'tt0104036', 'tt0108394', 'tt0110963', 'tt0111495', 'tt0111797', 'tt0112445', 'tt0112887', 'tt0113677', 'tt0113947', 'tt0114388', 'tt0114594', 'tt0114746', 'tt0114906', 'tt0115012', 'tt0115906', 'tt0116191', 'tt0116209', 'tt0116722', 'tt0116905', 'tt0117589', 'tt0118607', 'tt0118929', 'tt0119177', 'tt0119558', 'tt0120188', 'tt0120255', 'tt0120338', 'tt0120586', 'tt0120601', 'tt0120631', 'tt0120777', 'tt0126886', 'tt0127536', 'tt0138097']
# object
# bucket_4_5_count
# 83.0
# float64
# bucket_4_5_year_avg
# 1982.710843373494
# float64
# bucket_4_5_year_var
# 242.20805171907136
# float64
# bucket_4_5_runtime_avg
# 122.71084337349397
# float64
# bucket_4_5_runtime_var
# 642.8178078166325
# float64
# bucket_4_5_rating_avg
# 7.73132530120482
# float64
# bucket_4_5_rating_var
# 0.3626652953276522
# float64
# bucket_4_5_numvotes_avg
# 305535.4698795181
# float64
# bucket_4_5_numvotes_var
# 152106428030.7888
# float64
# bucket_4_5_top_directors
# ['nm0000217', 'nm0001425', 'nm0000041']
# object
# bucket_4_5_top_writers
# ['nm0000338', 'nm0932229', 'nm0000697']
# object
# ratio_bucket_0_1_to_bucket_2_3
# 0.8125
# float64
# year_avg_diff_bucket_0_1_vs_bucket_2_3
# 3.2620192307692832
# float64
# runtime_avg_diff_bucket_0_1_vs_bucket_2_3
# 7.730769230769226
# float64
# rating_avg_diff_bucket_0_1_vs_bucket_2_3
# -0.1634615384615392
# float64
# ratio_bucket_0_1_to_bucket_4_5
# 0.3132530120481928
# float64
# year_avg_diff_bucket_0_1_vs_bucket_4_5
# 6.5199258572752115
# float64
# runtime_avg_diff_bucket_0_1_vs_bucket_4_5
# 4.019925857275254
# float64
# rating_avg_diff_bucket_0_1_vs_bucket_4_5
# -0.2197868396663596
# float64
# ratio_bucket_2_3_to_bucket_4_5
# 0.3855421686746988
# float64
# year_avg_diff_bucket_2_3_vs_bucket_4_5
# 3.257906626505928
# float64
# runtime_avg_diff_bucket_2_3_vs_bucket_4_5
# -3.7108433734939723
# float64
# rating_avg_diff_bucket_2_3_vs_bucket_4_5
# -0.05632530120482038
# float64
# high_vs_low_ratio
# 0.0
# float64
# overall_movie_ids
# ['tt0032143', 'tt0033467', 'tt0034583', 'tt0036868', 'tt0042192', 'tt0042546', 'tt0045793', 'tt0046250', 'tt0047437', 'tt0048728', 'tt0050083', 'tt0050825', 'tt0051459', 'tt0053125', 'tt0053604', 'tt0055630', 'tt0056172', 'tt0057115', 'tt0059113', 'tt0061512', 'tt0061578', 'tt0061722', 'tt0063442', 'tt0064115', 'tt0064665', 'tt0065377', 'tt0066206', 'tt0070735', 'tt0071562', 'tt0071853', 'tt0075314', 'tt0076759', 'tt0077416', 'tt0078346', 'tt0078788', 'tt0079367', 'tt0079470', 'tt0080678', 'tt0080684', 'tt0081398', 'tt0082096', 'tt0083658', 'tt0084589', 'tt0085244', 'tt0086190', 'tt0086879', 'tt0087995', 'tt0088258', 'tt0088763', 'tt0088846', 'tt0088847', 'tt0088933', 'tt0089881', 'tt0089886', 'tt0090605', 'tt0090830', 'tt0091042', 'tt0091763', 'tt0091867', 'tt0092005', 'tt0092699', 'tt0093191', 'tt0093389', 'tt0093779', 'tt0093870', 'tt0094737', 'tt0094947', 'tt0095593', 'tt0095765', 'tt0095953', 'tt0097123', 'tt0097441', 'tt0098213', 'tt0099685', 'tt0102926', 'tt0103130', 'tt0104036', 'tt0104257', 'tt0108052', 'tt0108394', 'tt0109045', 'tt0109445', 'tt0109830', 'tt0110963', 'tt0111495', 'tt0111797', 'tt0112431', 'tt0112445', 'tt0112573', 'tt0112682', 'tt0112740', 'tt0112769', 'tt0112818', 'tt0112887', 'tt0113627', 'tt0113677', 'tt0113947', 'tt0114388', 'tt0114594', 'tt0114746', 'tt0114906', 'tt0115012', 'tt0115906', 'tt0116191', 'tt0116209', 'tt0116282', 'tt0116353', 'tt0116722', 'tt0116905', 'tt0117318', 'tt0117589', 'tt0117631', 'tt0117802', 'tt0118607', 'tt0118799', 'tt0118929', 'tt0119177', 'tt0119558', 'tt0119822', 'tt0119942', 'tt0120188', 'tt0120255', 'tt0120338', 'tt0120586', 'tt0120601', 'tt0120631', 'tt0120663', 'tt0120716', 'tt0120777', 'tt0120815', 'tt0122541', 'tt0123755', 'tt0126886', 'tt0127536', 'tt0128853', 'tt0129387', 'tt0138097', 'tt0151804', 'tt0163187', 'tt0165859', 'tt0166896']
# object
# overall_count
# 141
# int64
# overall_year_avg
# 1984.6524822695035
# float64
# overall_year_var
# 221.7140830800405
# float64
# overall_runtime_avg
# 122.60992907801419
# float64
# overall_runtime_var
# 725.5967578520773
# float64
# overall_rating_avg
# 7.678014184397164
# float64
# overall_rating_var
# 0.3974417426545085
# float64
# overall_numvotes_avg
# 316521.5319148936
# float64
# overall_numvotes_var
# 181140019850.03653
# float64
# overall_top_directors
# ['nm0001661', 'nm0000229', 'nm0000416']
# object
# overall_top_writers
# ['nm0001410', 'nm0000184', 'nm0000416']
# object
# rating_proportions_0.5
# 0.0
# float64
# rating_proportions_1.0
# 0.18439716312056736
# float64
# rating_proportions_2.0
# 0.09219858156028368
# float64
# rating_proportions_3.0
# 0.1347517730496454
# float64
# rating_proportions_4.0
# 0.18439716312056736
# float64
# rating_proportions_5.0
# 0.40425531914893614
# float64
# rating_proportions_3.5
# 0.0
# float64
# rating_proportions_2.5
# 0.0
# float64
# rating_proportions_4.5
# 0.0
# float64
# rating_proportions_1.5
# 0.0
# float64
# bucket_0_1_genre_proportions_Family
# 0.015625
# float64
# bucket_0_1_genre_proportions_Animation
# 0.0
# float64
# bucket_0_1_genre_proportions_Sci-Fi
# 0.015625
# float64
# bucket_0_1_genre_proportions_Thriller
# 0.046875
# float64
# bucket_0_1_genre_proportions_Comedy
# 0.1875
# float64
# bucket_0_1_genre_proportions_Biography
# 0.09375
# float64
# bucket_0_1_genre_proportions_Adventure
# 0.046875
# float64
# bucket_0_1_genre_proportions_Action
# 0.015625
# float64
# bucket_0_1_genre_proportions_Romance
# 0.125
# float64
# bucket_0_1_genre_proportions_Horror
# 0.0
# float64
# bucket_0_1_genre_proportions_Drama
# 0.3125
# float64
# bucket_0_1_genre_proportions_Fantasy
# 0.015625
# float64
# bucket_0_1_genre_proportions_Mystery
# 0.015625
# float64
# bucket_0_1_genre_proportions_Crime
# 0.015625
# float64
# bucket_0_1_genre_proportions_War
# 0.03125
# float64
# bucket_2_3_genre_proportions_Family
# 0.012987012987012988
# float64
# bucket_2_3_genre_proportions_Animation
# 0.0
# float64
# bucket_2_3_genre_proportions_Sci-Fi
# 0.03896103896103896
# float64
# bucket_2_3_genre_proportions_Thriller
# 0.03896103896103896
# float64
# bucket_2_3_genre_proportions_Comedy
# 0.14285714285714285
# float64
# bucket_2_3_genre_proportions_Biography
# 0.03896103896103896
# float64
# bucket_2_3_genre_proportions_Adventure
# 0.025974025974025976
# float64
# bucket_2_3_genre_proportions_Action
# 0.012987012987012988
# float64
# bucket_2_3_genre_proportions_Romance
# 0.11688311688311688
# float64
# bucket_2_3_genre_proportions_Horror
# 0.025974025974025976
# float64
# bucket_2_3_genre_proportions_Drama
# 0.3116883116883117
# float64
# bucket_2_3_genre_proportions_Fantasy
# 0.05194805194805195
# float64
# bucket_2_3_genre_proportions_Mystery
# 0.012987012987012988
# float64
# bucket_2_3_genre_proportions_Crime
# 0.07792207792207792
# float64
# bucket_2_3_genre_proportions_War
# 0.05194805194805195
# float64
# bucket_4_5_genre_proportions_Family
# 0.004739336492890996
# float64
# bucket_4_5_genre_proportions_Animation
# 0.0
# float64
# bucket_4_5_genre_proportions_Sci-Fi
# 0.04265402843601896
# float64
# bucket_4_5_genre_proportions_Thriller
# 0.023696682464454975
# float64
# bucket_4_5_genre_proportions_Comedy
# 0.13744075829383887
# float64
# bucket_4_5_genre_proportions_Biography
# 0.04265402843601896
# float64
# bucket_4_5_genre_proportions_Adventure
# 0.052132701421800945
# float64
# bucket_4_5_genre_proportions_Action
# 0.052132701421800945
# float64
# bucket_4_5_genre_proportions_Romance
# 0.0995260663507109
# float64
# bucket_4_5_genre_proportions_Horror
# 0.004739336492890996
# float64
# bucket_4_5_genre_proportions_Drama
# 0.3127962085308057
# float64
# bucket_4_5_genre_proportions_Fantasy
# 0.023696682464454975
# float64
# bucket_4_5_genre_proportions_Mystery
# 0.04265402843601896
# float64
# bucket_4_5_genre_proportions_Crime
# 0.06635071090047394
# float64
# bucket_4_5_genre_proportions_War
# 0.04739336492890995
# float64
# overall_genre_proportions_Family
# 0.008522727272727272
# float64
# overall_genre_proportions_Animation
# 0.0
# float64
# overall_genre_proportions_Sci-Fi
# 0.036931818181818184
# float64
# overall_genre_proportions_Thriller
# 0.03125
# float64
# overall_genre_proportions_Comedy
# 0.14772727272727273
# float64
# overall_genre_proportions_Biography
# 0.05113636363636364
# float64
# overall_genre_proportions_Adventure
# 0.045454545454545456
# float64
# overall_genre_proportions_Action
# 0.036931818181818184
# float64
# overall_genre_proportions_Romance
# 0.10795454545454546
# float64
# overall_genre_proportions_Horror
# 0.008522727272727272
# float64
# overall_genre_proportions_Drama
# 0.3125
# float64
# overall_genre_proportions_Fantasy
# 0.028409090909090908
# float64
# overall_genre_proportions_Mystery
# 0.03125
# float64
# overall_genre_proportions_Crime
# 0.05965909090909091
# float64
# overall_genre_proportions_War
# 0.045454545454545456
# float64
# startYear
# 1995
# object
# runtimeMinutes
# 136
# object
# genres
# ['Drama', 'Romance']
# object
# averageRating
# 7.7
# float64
# numVotes
# 130226
# int64
# directors
# ['nm0000487']
# object
# writers
# ['nm0000807', 'nm0000668']
# object
# bucket_0_1_genre_proportions_Other
# 0.0625
# float64
# bucket_2_3_genre_proportions_Other
# 0.03896103896103896
# float64
# bucket_4_5_genre_proportions_Other
# 0.04739336492890995
# float64
# overall_genre_proportions_Other
# 0.04829545454545454
# float64
# tconst_str
# tt114388
# object

# %% [markdown]
# ### Do Further Feature Reduction

# %%
var_columns = combined_features.columns[combined_features.columns.str.contains("var")]
var_columns
# Out:
# Index(['bucket_0_1_year_var', 'bucket_0_1_runtime_var',
#        'bucket_0_1_rating_var', 'bucket_0_1_numvotes_var',
#        'bucket_2_3_year_var', 'bucket_2_3_runtime_var',
#        'bucket_2_3_rating_var', 'bucket_2_3_numvotes_var',
#        'bucket_4_5_year_var', 'bucket_4_5_runtime_var',
#        'bucket_4_5_rating_var', 'bucket_4_5_numvotes_var', 'overall_year_var',
#        'overall_runtime_var', 'overall_rating_var', 'overall_numvotes_var'],
#       dtype='object')

# %%
combined_features.drop(var_columns, inplace = True, axis = 1)
combined_features
# Out:
#           rating  total_ratings  rating_avg  rating_std  \
# 0            4.0            141    3.531915    1.537870
# 1            1.0            141    3.531915    1.537870
# 2            2.0            141    3.531915    1.537870
# 3            5.0            141    3.531915    1.537870
# 4            5.0            141    3.531915    1.537870
# ...          ...            ...         ...         ...
# 31972555     4.5            236    3.595339    1.243887
# 31972556     1.0            236    3.595339    1.243887
# 31972557     0.5            236    3.595339    1.243887
# 31972558     3.5            236    3.595339    1.243887
# 31972559     4.5            236    3.595339    1.243887
#
#                                        bucket_0_1_movie_ids  bucket_0_1_count  \
# 0         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 1         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 2         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 3         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# 4         [tt0056172, tt0059113, tt0071853, tt0079367, t...              26.0
# ...                                                     ...               ...
# 31972555  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972556  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972557  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972558  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
# 31972559  [tt0063462, tt0080761, tt0087800, tt0113198, t...              21.0
#
#           bucket_0_1_year_avg  bucket_0_1_runtime_avg  bucket_0_1_rating_avg  \
# 0                 1989.230769              126.730769               7.511538
# 1                 1989.230769              126.730769               7.511538
# 2                 1989.230769              126.730769               7.511538
# 3                 1989.230769              126.730769               7.511538
# 4                 1989.230769              126.730769               7.511538
# ...                       ...                     ...                    ...
# 31972555          1999.904762               96.952381               5.447619
# 31972556          1999.904762               96.952381               5.447619
# 31972557          1999.904762               96.952381               5.447619
# 31972558          1999.904762               96.952381               5.447619
# 31972559          1999.904762               96.952381               5.447619
#
#           bucket_0_1_numvotes_avg  ...                       genres  \
# 0                   220789.076923  ...             [Drama, Romance]
# 1                   220789.076923  ...             [Drama, Romance]
# 2                   220789.076923  ...  [Adventure, Drama, Fantasy]
# 3                   220789.076923  ...      [Crime, Drama, History]
# 4                   220789.076923  ...  [Mystery, Sci-Fi, Thriller]
# ...                           ...  ...                          ...
# 31972555            126668.428571  ...    [Action, Comedy, Fantasy]
# 31972556            126668.428571  ...     [Action, Drama, History]
# 31972557            126668.428571  ...             [Comedy, Horror]
# 31972558            126668.428571  ...           [Biography, Drama]
# 31972559            126668.428571  ...     [Comedy, Drama, Romance]
#
#          averageRating numVotes               directors  \
# 0                  7.7   130226             [nm0000487]
# 1                  7.5   139377             [nm0001214]
# 2                  7.5    72979  [nm0001988, nm0000466]
# 3                  7.1     6155             [nm0955443]
# 4                  8.0   660616             [nm0000416]
# ...                ...      ...                     ...
# 31972555           7.5   478444             [nm0942367]
# 31972556           6.3    87775             [nm0551076]
# 31972557           3.4    52852  [nm0294997, nm0783536]
# 31972558           7.8   783018             [nm0000399]
# 31972559           7.2    95719             [nm0590122]
#
#                                                writers  \
# 0                               [nm0000807, nm0000668]
# 1                               [nm3840714, nm0001214]
# 2         [nm0012496, nm0000466, nm0001988, nm0491011]
# 3                    [nm0270819, nm0910841, nm0944481]
# 4                    [nm0003408, nm0672459, nm0672466]
# ...                                                ...
# 31972555             [nm0045209, nm0942367, nm1854069]
# 31972556                                   [nm0551076]
# 31972557                        [nm0294997, nm0783536]
# 31972558                        [nm0815070, nm0583826]
# 31972559                                   [nm0590122]
#
#           bucket_0_1_genre_proportions_Other  \
# 0                                   0.062500
# 1                                   0.062500
# 2                                   0.062500
# 3                                   0.062500
# 4                                   0.062500
# ...                                      ...
# 31972555                            0.074074
# 31972556                            0.074074
# 31972557                            0.074074
# 31972558                            0.074074
# 31972559                            0.074074
#
#           bucket_2_3_genre_proportions_Other  \
# 0                                   0.038961
# 1                                   0.038961
# 2                                   0.038961
# 3                                   0.038961
# 4                                   0.038961
# ...                                      ...
# 31972555                            0.021583
# 31972556                            0.021583
# 31972557                            0.021583
# 31972558                            0.021583
# 31972559                            0.021583
#
#           bucket_4_5_genre_proportions_Other overall_genre_proportions_Other  \
# 0                                   0.047393                        0.048295
# 1                                   0.047393                        0.048295
# 2                                   0.047393                        0.048295
# 3                                   0.047393                        0.048295
# 4                                   0.047393                        0.048295
# ...                                      ...                             ...
# 31972555                            0.034582                        0.032841
# 31972556                            0.034582                        0.032841
# 31972557                            0.034582                        0.032841
# 31972558                            0.034582                        0.032841
# 31972559                            0.034582                        0.032841
#
#          tconst_str
# 0          tt114388
# 1          tt113627
# 2          tt112682
# 3          tt115012
# 4          tt114746
# ...             ...
# 31972555   tt446029
# 31972556  tt1020558
# 31972557  tt1666186
# 31972558  tt1285016
# 31972559  tt1532503
#
# [31972560 rows x 131 columns]

# %%
combined_features.to_pickle("./Datasets/Features3.10/combined_features2.0small.pkl")

# %%
combined_features.to_parquet("./Datasets/Features3.10/combined_features2.0small.parquet")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Convert Into Vaex compatible format

# %%
for col in combined_features.columns:
    print(col)
    print(combined_features[col].dtype)
    print(combined_features[col][0])
# Out:
# rating
# float64
# 4.0
# total_ratings
# int64
# 141
# rating_avg
# float64
# 3.5319148936170213
# rating_std
# float64
# 1.5378704733185982
# bucket_0_1_movie_ids
# object
# ['tt0056172', 'tt0059113', 'tt0071853', 'tt0079367', 'tt0079470', 'tt0088933', 'tt0090830', 'tt0092699', 'tt0093389', 'tt0093779', 'tt0095953', 'tt0097441', 'tt0104257', 'tt0109045', 'tt0112740', 'tt0112818', 'tt0113627', 'tt0117318', 'tt0117631', 'tt0118799', 'tt0119822', 'tt0120663', 'tt0120716', 'tt0128853', 'tt0163187', 'tt0166896']
# bucket_0_1_count
# float64
# 26.0
# bucket_0_1_year_avg
# float64
# 1989.2307692307693
# bucket_0_1_runtime_avg
# float64
# 126.73076923076923
# bucket_0_1_rating_avg
# float64
# 7.511538461538461
# bucket_0_1_numvotes_avg
# float64
# 220789.07692307694
# bucket_0_1_top_directors
# object
# ['nm0000180', 'nm0001402', 'nm0000985']
# bucket_0_1_top_writers
# object
# ['nm0004122', 'nm0001385', 'nm0001589']
# bucket_2_3_movie_ids
# object
# ['tt0034583', 'tt0042546', 'tt0045793', 'tt0051459', 'tt0061512', 'tt0064115', 'tt0085244', 'tt0086190', 'tt0087995', 'tt0088846', 'tt0091867', 'tt0093191', 'tt0095765', 'tt0098213', 'tt0102926', 'tt0108052', 'tt0109445', 'tt0109830', 'tt0112431', 'tt0112573', 'tt0112682', 'tt0112769', 'tt0116282', 'tt0116353', 'tt0117802', 'tt0119942', 'tt0120815', 'tt0122541', 'tt0123755', 'tt0129387', 'tt0151804', 'tt0165859']
# bucket_2_3_count
# float64
# 32.0
# bucket_2_3_year_avg
# float64
# 1985.96875
# bucket_2_3_runtime_avg
# float64
# 119.0
# bucket_2_3_rating_avg
# float64
# 7.675
# bucket_2_3_numvotes_avg
# float64
# 422799.25
# bucket_2_3_top_directors
# object
# ['nm0000229', 'nm0002031', 'nm0371852']
# bucket_2_3_top_writers
# object
# ['nm0001410', 'nm0001054', 'nm0001053']
# bucket_4_5_movie_ids
# object
# ['tt0032143', 'tt0033467', 'tt0036868', 'tt0042192', 'tt0046250', 'tt0047437', 'tt0048728', 'tt0050083', 'tt0050825', 'tt0053125', 'tt0053604', 'tt0055630', 'tt0057115', 'tt0061578', 'tt0061722', 'tt0063442', 'tt0064665', 'tt0065377', 'tt0066206', 'tt0070735', 'tt0071562', 'tt0075314', 'tt0076759', 'tt0077416', 'tt0078346', 'tt0078788', 'tt0080678', 'tt0080684', 'tt0081398', 'tt0082096', 'tt0083658', 'tt0084589', 'tt0086879', 'tt0088258', 'tt0088763', 'tt0088847', 'tt0089881', 'tt0089886', 'tt0090605', 'tt0091042', 'tt0091763', 'tt0092005', 'tt0093870', 'tt0094737', 'tt0094947', 'tt0095593', 'tt0097123', 'tt0099685', 'tt0103130', 'tt0104036', 'tt0108394', 'tt0110963', 'tt0111495', 'tt0111797', 'tt0112445', 'tt0112887', 'tt0113677', 'tt0113947', 'tt0114388', 'tt0114594', 'tt0114746', 'tt0114906', 'tt0115012', 'tt0115906', 'tt0116191', 'tt0116209', 'tt0116722', 'tt0116905', 'tt0117589', 'tt0118607', 'tt0118929', 'tt0119177', 'tt0119558', 'tt0120188', 'tt0120255', 'tt0120338', 'tt0120586', 'tt0120601', 'tt0120631', 'tt0120777', 'tt0126886', 'tt0127536', 'tt0138097']
# bucket_4_5_count
# float64
# 83.0
# bucket_4_5_year_avg
# float64
# 1982.710843373494
# bucket_4_5_runtime_avg
# float64
# 122.71084337349397
# bucket_4_5_rating_avg
# float64
# 7.73132530120482
# bucket_4_5_numvotes_avg
# float64
# 305535.4698795181
# bucket_4_5_top_directors
# object
# ['nm0000217', 'nm0001425', 'nm0000041']
# bucket_4_5_top_writers
# object
# ['nm0000338', 'nm0932229', 'nm0000697']
# ratio_bucket_0_1_to_bucket_2_3
# float64
# 0.8125
# year_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# 3.2620192307692832
# runtime_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# 7.730769230769226
# rating_avg_diff_bucket_0_1_vs_bucket_2_3
# float64
# -0.1634615384615392
# ratio_bucket_0_1_to_bucket_4_5
# float64
# 0.3132530120481928
# year_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# 6.5199258572752115
# runtime_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# 4.019925857275254
# rating_avg_diff_bucket_0_1_vs_bucket_4_5
# float64
# -0.2197868396663596
# ratio_bucket_2_3_to_bucket_4_5
# float64
# 0.3855421686746988
# year_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# 3.257906626505928
# runtime_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# -3.7108433734939723
# rating_avg_diff_bucket_2_3_vs_bucket_4_5
# float64
# -0.05632530120482038
# high_vs_low_ratio
# float64
# 0.0
# overall_movie_ids
# object
# ['tt0032143', 'tt0033467', 'tt0034583', 'tt0036868', 'tt0042192', 'tt0042546', 'tt0045793', 'tt0046250', 'tt0047437', 'tt0048728', 'tt0050083', 'tt0050825', 'tt0051459', 'tt0053125', 'tt0053604', 'tt0055630', 'tt0056172', 'tt0057115', 'tt0059113', 'tt0061512', 'tt0061578', 'tt0061722', 'tt0063442', 'tt0064115', 'tt0064665', 'tt0065377', 'tt0066206', 'tt0070735', 'tt0071562', 'tt0071853', 'tt0075314', 'tt0076759', 'tt0077416', 'tt0078346', 'tt0078788', 'tt0079367', 'tt0079470', 'tt0080678', 'tt0080684', 'tt0081398', 'tt0082096', 'tt0083658', 'tt0084589', 'tt0085244', 'tt0086190', 'tt0086879', 'tt0087995', 'tt0088258', 'tt0088763', 'tt0088846', 'tt0088847', 'tt0088933', 'tt0089881', 'tt0089886', 'tt0090605', 'tt0090830', 'tt0091042', 'tt0091763', 'tt0091867', 'tt0092005', 'tt0092699', 'tt0093191', 'tt0093389', 'tt0093779', 'tt0093870', 'tt0094737', 'tt0094947', 'tt0095593', 'tt0095765', 'tt0095953', 'tt0097123', 'tt0097441', 'tt0098213', 'tt0099685', 'tt0102926', 'tt0103130', 'tt0104036', 'tt0104257', 'tt0108052', 'tt0108394', 'tt0109045', 'tt0109445', 'tt0109830', 'tt0110963', 'tt0111495', 'tt0111797', 'tt0112431', 'tt0112445', 'tt0112573', 'tt0112682', 'tt0112740', 'tt0112769', 'tt0112818', 'tt0112887', 'tt0113627', 'tt0113677', 'tt0113947', 'tt0114388', 'tt0114594', 'tt0114746', 'tt0114906', 'tt0115012', 'tt0115906', 'tt0116191', 'tt0116209', 'tt0116282', 'tt0116353', 'tt0116722', 'tt0116905', 'tt0117318', 'tt0117589', 'tt0117631', 'tt0117802', 'tt0118607', 'tt0118799', 'tt0118929', 'tt0119177', 'tt0119558', 'tt0119822', 'tt0119942', 'tt0120188', 'tt0120255', 'tt0120338', 'tt0120586', 'tt0120601', 'tt0120631', 'tt0120663', 'tt0120716', 'tt0120777', 'tt0120815', 'tt0122541', 'tt0123755', 'tt0126886', 'tt0127536', 'tt0128853', 'tt0129387', 'tt0138097', 'tt0151804', 'tt0163187', 'tt0165859', 'tt0166896']
# overall_count
# int64
# 141
# overall_year_avg
# float64
# 1984.6524822695035
# overall_runtime_avg
# float64
# 122.60992907801419
# overall_rating_avg
# float64
# 7.678014184397164
# overall_numvotes_avg
# float64
# 316521.5319148936
# overall_top_directors
# object
# ['nm0001661', 'nm0000229', 'nm0000416']
# overall_top_writers
# object
# ['nm0001410', 'nm0000184', 'nm0000416']
# rating_proportions_0.5
# float64
# 0.0
# rating_proportions_1.0
# float64
# 0.18439716312056736
# rating_proportions_2.0
# float64
# 0.09219858156028368
# rating_proportions_3.0
# float64
# 0.1347517730496454
# rating_proportions_4.0
# float64
# 0.18439716312056736
# rating_proportions_5.0
# float64
# 0.40425531914893614
# rating_proportions_3.5
# float64
# 0.0
# rating_proportions_2.5
# float64
# 0.0
# rating_proportions_4.5
# float64
# 0.0
# rating_proportions_1.5
# float64
# 0.0
# bucket_0_1_genre_proportions_Adventure
# float64
# 0.046875
# bucket_0_1_genre_proportions_Thriller
# float64
# 0.046875
# bucket_0_1_genre_proportions_Romance
# float64
# 0.125
# bucket_0_1_genre_proportions_Fantasy
# float64
# 0.015625
# bucket_0_1_genre_proportions_Horror
# float64
# 0.0
# bucket_0_1_genre_proportions_Crime
# float64
# 0.015625
# bucket_0_1_genre_proportions_Sci-Fi
# float64
# 0.015625
# bucket_0_1_genre_proportions_Biography
# float64
# 0.09375
# bucket_0_1_genre_proportions_Family
# float64
# 0.015625
# bucket_0_1_genre_proportions_Comedy
# float64
# 0.1875
# bucket_0_1_genre_proportions_Drama
# float64
# 0.3125
# bucket_0_1_genre_proportions_Action
# float64
# 0.015625
# bucket_0_1_genre_proportions_Animation
# float64
# 0.0
# bucket_0_1_genre_proportions_Mystery
# float64
# 0.015625
# bucket_0_1_genre_proportions_War
# float64
# 0.03125
# bucket_2_3_genre_proportions_Thriller
# float64
# 0.03896103896103896
# bucket_2_3_genre_proportions_Adventure
# float64
# 0.025974025974025976
# bucket_2_3_genre_proportions_Romance
# float64
# 0.11688311688311688
# bucket_2_3_genre_proportions_Fantasy
# float64
# 0.05194805194805195
# bucket_2_3_genre_proportions_Horror
# float64
# 0.025974025974025976
# bucket_2_3_genre_proportions_Crime
# float64
# 0.07792207792207792
# bucket_2_3_genre_proportions_Sci-Fi
# float64
# 0.03896103896103896
# bucket_2_3_genre_proportions_Biography
# float64
# 0.03896103896103896
# bucket_2_3_genre_proportions_Family
# float64
# 0.012987012987012988
# bucket_2_3_genre_proportions_Comedy
# float64
# 0.14285714285714285
# bucket_2_3_genre_proportions_Drama
# float64
# 0.3116883116883117
# bucket_2_3_genre_proportions_Action
# float64
# 0.012987012987012988
# bucket_2_3_genre_proportions_Animation
# float64
# 0.0
# bucket_2_3_genre_proportions_Mystery
# float64
# 0.012987012987012988
# bucket_2_3_genre_proportions_War
# float64
# 0.05194805194805195
# bucket_4_5_genre_proportions_Adventure
# float64
# 0.052132701421800945
# bucket_4_5_genre_proportions_Thriller
# float64
# 0.023696682464454975
# bucket_4_5_genre_proportions_Romance
# float64
# 0.0995260663507109
# bucket_4_5_genre_proportions_Fantasy
# float64
# 0.023696682464454975
# bucket_4_5_genre_proportions_Horror
# float64
# 0.004739336492890996
# bucket_4_5_genre_proportions_Crime
# float64
# 0.06635071090047394
# bucket_4_5_genre_proportions_Sci-Fi
# float64
# 0.04265402843601896
# bucket_4_5_genre_proportions_Biography
# float64
# 0.04265402843601896
# bucket_4_5_genre_proportions_Family
# float64
# 0.004739336492890996
# bucket_4_5_genre_proportions_Comedy
# float64
# 0.13744075829383887
# bucket_4_5_genre_proportions_Drama
# float64
# 0.3127962085308057
# bucket_4_5_genre_proportions_Action
# float64
# 0.052132701421800945
# bucket_4_5_genre_proportions_Animation
# float64
# 0.0
# bucket_4_5_genre_proportions_Mystery
# float64
# 0.04265402843601896
# bucket_4_5_genre_proportions_War
# float64
# 0.04739336492890995
# overall_genre_proportions_Adventure
# float64
# 0.045454545454545456
# overall_genre_proportions_Thriller
# float64
# 0.03125
# overall_genre_proportions_Romance
# float64
# 0.10795454545454546
# overall_genre_proportions_Fantasy
# float64
# 0.028409090909090908
# overall_genre_proportions_Horror
# float64
# 0.008522727272727272
# overall_genre_proportions_Crime
# float64
# 0.05965909090909091
# overall_genre_proportions_Sci-Fi
# float64
# 0.036931818181818184
# overall_genre_proportions_Biography
# float64
# 0.05113636363636364
# overall_genre_proportions_Family
# float64
# 0.008522727272727272
# overall_genre_proportions_Comedy
# float64
# 0.14772727272727273
# overall_genre_proportions_Drama
# float64
# 0.3125
# overall_genre_proportions_Action
# float64
# 0.036931818181818184
# overall_genre_proportions_Animation
# float64
# 0.0
# overall_genre_proportions_Mystery
# float64
# 0.03125
# overall_genre_proportions_War
# float64
# 0.045454545454545456
# startYear
# object
# 1995
# runtimeMinutes
# object
# 136
# genres
# object
# ['Drama', 'Romance']
# averageRating
# float64
# 7.7
# numVotes
# int64
# 130226
# directors
# object
# ['nm0000487']
# writers
# object
# ['nm0000807', 'nm0000668']
# bucket_0_1_genre_proportions_Other
# float64
# 0.0625
# bucket_2_3_genre_proportions_Other
# float64
# 0.03896103896103896
# bucket_4_5_genre_proportions_Other
# float64
# 0.04739336492890995
# overall_genre_proportions_Other
# float64
# 0.048295454545454544
# tconst_str
# object
# tt114388

# %% [markdown]
# ### Load in Pkl

# %%
filtered = pd.read_pickle("./Datasets/Features/combined_features2.0med.pkl")

# %%
drop_proportion = 0.5
# Get original dataset size
original_size = len(filtered)
print(f"Original dataset: {original_size} rows and {len(df.columns)} columns")

# Calculate how many rows to drop
rows_to_drop = int(original_size * (1 - drop_proportion))

# Generate indices to drop (random selection)
import numpy as np
drop_indices = np.random.choice(filtered.index, size=rows_to_drop, replace=False)

# Drop rows in-place to avoid creating a full copy
filtered.drop(drop_indices, inplace=True)
# Out:
# Original dataset: 31972560 rows and 186 columns

# %%
len(filtered)
# Out:
# 15986280

# %%
filtered.to_pickle("./Datasets/Features/combined_features2.0small.pkl")

# %%
filtered["bucket_0_1_movie_ids"].dtype
# Out:
# dtype('O')

# %%
filtered["bucket_0_1_movie_ids"][0]
# Out:
# list

# %%
empty_values = filtered["bucket_0_1_movie_ids"].isna()

# %%
object_columns = filtered.select_dtypes(include="object").columns

# %%
object_columns
# Out:
# Index(['bucket_0_1_movie_ids', 'bucket_0_1_top_directors',
#        'bucket_0_1_top_writers', 'bucket_2_3_movie_ids',
#        'bucket_2_3_top_directors', 'bucket_2_3_top_writers',
#        'bucket_4_5_movie_ids', 'bucket_4_5_top_directors',
#        'bucket_4_5_top_writers', 'overall_movie_ids', 'overall_top_directors',
#        'overall_top_writers', 'startYear', 'runtimeMinutes', 'genres',
#        'directors', 'writers', 'tconst_str'],
#       dtype='object')

# %% [markdown]
# ### Verify that Object Columns are Consistent

# %%
filtered["runtimeMinutes"]
# Out:
# 0           136
# 1           111
# 2           112
# 4           129
# 6           122
#            ...
# 31972550    109
# 31972553     98
# 31972556     97
# 31972557     82
# 31972559    105
# Name: runtimeMinutes, Length: 15986280, dtype: object

# %%
filtered["runtimeMinutes"] = pd.to_numeric(filtered["runtimeMinutes"], errors='coerce').astype("Int64")

# %% [markdown]
# ### Divide Columns into Types

# %%
### How would I do this
### Divide into object columns
    ### Divide into strings
    ### Divide into 
### Divide into Non-object

# %%
for col in object_columns:
    if col not in filtered.columns:
        print(f"Column '{col}' not found in DataFrame.")
        continue
    
    # Get unique types in the column (excluding NaNs)
    unique_types = set(filtered[col].dropna().map(type))
#    if len(unique_types) == 1:
#        print(f"✅ Column '{col}' is consistent. Type: {list(unique_types)[0].__name__}")
    if len(unique_types) > 1:
        print(f"❌ Column '{col}' is inconsistent. Found types: {unique_types}")
    else:
        print(unique_types)
# Out:
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'str'>}
# {<class 'int'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'list'>}
# {<class 'str'>}

# %%
list_columns = []
string_columns = []

for col in object_columns:
    if col not in filtered.columns:
        print(f"Column '{col}' not found in DataFrame.")
        continue
    
    # Get unique types in the column (excluding NaNs)
    unique_types = set(filtered[col].dropna().map(type))
    
    # Categorize based on type
    if len(unique_types) == 1:  # Only process consistent type columns
        col_type = list(unique_types)[0]
        if col_type == list:
            list_columns.append(col)
        elif col_type == str:
            string_columns.append(col)
    else:
        print(f"❌ Column '{col}' is inconsistent. Found types: {unique_types}")

print("\nList columns:", list_columns)
print("\nString columns:", string_columns)
# Out:
# List columns: ['bucket_0_1_movie_ids', 'bucket_0_1_top_directors', 'bucket_0_1_top_writers', 'bucket_2_3_movie_ids', 'bucket_2_3_top_directors', 'bucket_2_3_top_writers', 'bucket_4_5_movie_ids', 'bucket_4_5_top_directors', 'bucket_4_5_top_writers', 'overall_movie_ids', 'overall_top_directors', 'overall_top_writers', 'genres', 'directors', 'writers']
#
# String columns: ['startYear', 'tconst_str']

# %% [markdown]
# ### Handle StartYear

# %%
filtered["startYear"] = pd.to_numeric(filtered["startYear"], errors='coerce').astype("Int64")
filtered["startYear"]
# Out:
# 0           1995
# 1           1995
# 2           1995
# 4           1995
# 6           1995
#             ...
# 31972550    2009
# 31972553    2010
# 31972556    2010
# 31972557    2010
# 31972559    2010
# Name: startYear, Length: 15986280, dtype: Int64

# %% [markdown]
# ### To Parquet

# %%
filtered.to_parquet("./Datasets/Features/combined_features2.0small.parquet")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Define Schema for Parquet
# Do this if there is an inconsistency
