# %%
### Need to find filtered title.akas

### Question? How do you Handle duplicate Values? Focus on OriginalTitle I guess
### Movie Features:

### Title.basics
    ### IsAdult boolean
    ### StartYear Normalized
    ### Runtime Normalized
    ### Genres One hot Encoding
### Title.Crew
    ### Directors One hot Encoding
    ### Writers One hot Encoding
### Title.Principals
    ### nconst person who worked on the film 
    ### Category of person working
    ### Combine both category and person. Have one hot encoding for each category.
### Title.Ratings
    ### AverageRating Normalized
    ### NumVotes Normalized

    
### Failure 
### Cannot find original language and region of this movie 
### ### Titles.akas
    ### Region One Hot Encoding
    ### Language One Hot Encoding

# %% [markdown]
# ### Imports

# %% [markdown]
# ### Autoencoder Approach

# %% [markdown]
# ### Matrix Factorization

# %% [markdown]
# ### Factorization Machines

# %% [markdown]
# ### Hybrid Approach
# - Wide and Deep
#     - Needs manual feature engineering
# - DeepFM
#     - Takes into account feature interactions without the need for explicit programming
# - Scoring Approach
#     - Needs manual tuning of content based approach and collaborative filtering approach
# - Filter and Rerank

# %% [markdown]
# ### Content Based
# - Generate content embeddings and take similarity
#     - Embeddings based on bag of words
#     - Genres
#     - Cast
#     - Year
#     - Rating
#     - Language
#     - Country

# %% [markdown]
# ### Collaborative Filtering
# - Matrix Factorization
#     - Find latent vectors to represent movies and users
#     - Either do optimization step for new users
#     - Either take the average for the user input
# - Item Based Collaborative Filtering
# - User Based Collaborative Filtering
# - Neural Collaborative Filtering

# %% [markdown]
# ### Deep FM Implementation
# - Features
#     - User Features
#         - User Movie Ratings
#         - User Movie Genres
#         - Movies and Their Ratings
#         - Or Movies the User has watched
#         - Or movies the user has disliked
#         -
#     - Item Features
# - Output
#     - Expected User's Rating of a Given Movie
# - Final Output is the top n movies the user would like.
#     - I wonder how long does an inference iteration take for 8.7 million movies.
# - Maybe I need to do filter and rerank
# - Filter N number of movies Using a filtering approach and then rerank ratings between them.

# %% [markdown]
# ### Features
# - User Features
#     - Liked Movies (One Hot Encoded)
#     - Watched Movies (One Hot Encoded)
#     - Movies Watched Genres (Proportions)
#     - Movies Liked Genres (Proportions)
#     - Average Rating of Movies Watched
#     - Movie Ratings (Proportions)
#     - Movie Release Year (Averages)
#     - Average Runtime of Movies Watched
#     - Average Runtime of Movies Liked
#     - Proportion of Liked and Disliked Movies
#     - Preferred Languages
#     - Preferred Regiouns
#     - Preferred Directors
#     - Preferred Actors

# %%
### Construct User Information First by Sorting. 
### Construct Movie Feature Information. 
### For Row and Rating Construct Tabel with User Information and Movie Features

# %%
import pandas as pd 
import os

# %% [markdown]
# ### Load IMDB Movie Information

# %%
imdb_dir = "./Datasets/imdb-data-cleaned"


# Dictionary to store dataframes
imdb_data = {}

# List all files in the IMDB directory
for filename in os.listdir(imdb_dir):
    if filename.endswith('.csv'):  # IMDB files are typically tab-separated
        file_path = os.path.join(imdb_dir, filename)
        # Remove the .tsv extension to create the dictionary key
        key = filename.replace('.csv', '')
        # Read the TSV file
        imdb_data[key] = pd.read_csv(file_path, sep=',', low_memory=False)
        print(f"Loaded {filename} with shape {imdb_data[key].shape}")
# Out:
# Loaded title.episode.csv with shape (46, 4)
# Loaded title.crew.csv with shape (83955, 3)
# Loaded title.basics.csv with shape (83955, 9)
# Loaded title.principals.csv with shape (1523925, 6)
# Loaded title.ratings.csv with shape (83955, 3)
# Loaded title.basics.aka.csv with shape (135077, 9)

# %% [markdown]
# ### Create Dataframe with Movie Features

# %%
# Start with the base features from title.basics
movie_features = imdb_data["title.basics"][["tconst", "primaryTitle", "isAdult", "startYear", "runtimeMinutes", "genres"]]

# Convert genres from string to list
movie_features['genres'] = movie_features['genres'].fillna('').str.split(',')

# Merge ratings data
movie_features = movie_features.merge(
    imdb_data["title.ratings"][["tconst", "averageRating", "numVotes"]], 
    on="tconst", 
    how="left"
)

# Merge crew data (directors and writers)
movie_features = movie_features.merge(
    imdb_data["title.crew"][["tconst", "directors", "writers"]], 
    on="tconst", 
    how="left"
)

# Convert directors and writers from string to list
movie_features['directors'] = movie_features['directors'].fillna('').str.split(',')
movie_features['writers'] = movie_features['writers'].fillna('').str.split(',')

# Handle principals data (cast and crew)
principals = imdb_data["title.principals"][["tconst", "nconst", "category"]]
# Group by movie and category to get lists of people in each role
principals_grouped = principals.groupby(['tconst', 'category'])['nconst'].agg(list).reset_index()
# Pivot to create columns for each category
principals_pivot = principals_grouped.pivot(
    index='tconst',
    columns='category',
    values='nconst'
).reset_index()

# Merge principals data with main features
movie_features = movie_features.merge(
    principals_pivot,
    on="tconst",
    how="left"
)

# Fill NaN values in list columns with empty lists
list_columns = ['genres', 'directors', 'writers'] + list(principals_pivot.columns[1:])
for col in list_columns:
    if col in movie_features.columns:
        movie_features[col] = movie_features[col].fillna('').apply(lambda x: [] if x == '' else x)

print("Final dataset shape:", movie_features.shape)
movie_features.head()
# Out:
# /var/folders/jt/bd1fv_b11kv13vftmc5sqlgr0000gn/T/ipykernel_25266/1723179424.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_features['genres'] = movie_features['genres'].fillna('').str.split(',')
# Final dataset shape: (83955, 23)
#       tconst                                 primaryTitle  isAdult startYear  \
# 0  tt0000001                                   Carmencita        0      1894
# 1  tt0000003                                 Poor Pierrot        0      1892
# 2  tt0000007  Corbett and Courtney Before the Kinetograph        0      1894
# 3  tt0000008       Edison Kinetoscopic Record of a Sneeze        0      1894
# 4  tt0000010                          Leaving the Factory        0      1895
#
#   runtimeMinutes                        genres  averageRating  numVotes  \
# 0              1          [Documentary, Short]            5.7      2133
# 1              5  [Animation, Comedy, Romance]            6.4      2167
# 2              1                [Short, Sport]            5.3       900
# 3              1          [Documentary, Short]            5.4      2278
# 4              1          [Documentary, Short]            6.8      7865
#
#                 directors writers  ... archive_sound casting_director  \
# 0             [nm0005690]    [\N]  ...            []               []
# 1             [nm0721526]    [\N]  ...            []               []
# 2  [nm0005690, nm0374658]    [\N]  ...            []               []
# 3             [nm0005690]    [\N]  ...            []               []
# 4             [nm0525910]    [\N]  ...            []               []
#
#   cinematographer     composer                director       editor  \
# 0     [nm0374658]           []             [nm0005690]           []
# 1              []  [nm1335271]             [nm0721526]  [nm5442200]
# 2     [nm0374658]           []  [nm0005690, nm0374658]           []
# 3     [nm0374658]           []             [nm0005690]           []
# 4     [nm0525910]           []             [nm0525910]           []
#
#                  producer production_designer         self writer
# 0             [nm0005690]                  []  [nm1588970]     []
# 1  [nm1770680, nm0721526]                  []           []     []
# 2  [nm0005690, nm0249379]                  []           []     []
# 3             [nm0005690]                  []           []     []
# 4             [nm0525910]                  []           []     []
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Load User Information

# %%
### Ok I want to add imdb ID to links.csv as a column
links = pd.read_csv("./Datasets/ml-32m-cleaned/links.csv")
ratings = pd.read_csv("./Datasets/ml-32m-cleaned/ratings.csv")

# %%
len(links)
# Out:
# 83955

# %%
len(ratings["movieId"].unique())
# Out:
# 83955

# %%
combined = ratings.merge(
    links[["imdbId", "movieId"]],
    on = "movieId",
    how = "inner"
              )

# %%
len(combined["movieId"].unique())
# Out:
# 83955

# %%
### I want to create a user profile now.

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31972560 entries, 0 to 31972559
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
#  4   imdbId     int64
# dtypes: float64(1), int64(4)
# memory usage: 1.2 GB

# %%
movie_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83955 entries, 0 to 83954
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tconst               83955 non-null  object
#  1   primaryTitle         83955 non-null  object
#  2   isAdult              83955 non-null  int64
#  3   startYear            83955 non-null  object
#  4   runtimeMinutes       83955 non-null  object
#  5   genres               83955 non-null  object
#  6   averageRating        83955 non-null  float64
#  7   numVotes             83955 non-null  int64
#  8   directors            83955 non-null  object
#  9   writers              83955 non-null  object
#  10  actor                83955 non-null  object
#  11  actress              83955 non-null  object
#  12  archive_footage      83955 non-null  object
#  13  archive_sound        83955 non-null  object
#  14  casting_director     83955 non-null  object
#  15  cinematographer      83955 non-null  object
#  16  composer             83955 non-null  object
#  17  director             83955 non-null  object
#  18  editor               83955 non-null  object
#  19  producer             83955 non-null  object
#  20  production_designer  83955 non-null  object
#  21  self                 83955 non-null  object
#  22  writer               83955 non-null  object
# dtypes: float64(1), int64(2), object(20)
# memory usage: 14.7+ MB

# %%
print(combined.head(10))
movie_features.head(10)
# Out:
#    userId  movieId  rating  timestamp  imdbId
# 0       1       17     4.0  944249077  114388
# 1       1       25     1.0  944250228  113627
# 2       1       29     2.0  943230976  112682
# 3       1       30     5.0  944249077  115012
# 4       1       32     5.0  943228858  114746
# 5       1       34     2.0  943228491  112431
# 6       1       36     1.0  944249008  112818
# 7       1       80     5.0  944248943  112445
# 8       1      110     3.0  943231119  112573
# 9       1      111     5.0  944249008   75314
#       tconst                                 primaryTitle  isAdult startYear  \
# 0  tt0000001                                   Carmencita        0      1894
# 1  tt0000003                                 Poor Pierrot        0      1892
# 2  tt0000007  Corbett and Courtney Before the Kinetograph        0      1894
# 3  tt0000008       Edison Kinetoscopic Record of a Sneeze        0      1894
# 4  tt0000010                          Leaving the Factory        0      1895
# 5  tt0000012                       The Arrival of a Train        0      1896
# 6  tt0000013  The Photographical Congress Arrives in Lyon        0      1895
# 7  tt0000014                          The Waterer Watered        0      1895
# 8  tt0000015                               Around a Cabin        0      1894
# 9  tt0000016                        Boat Leaving the Port        0      1895
#
#   runtimeMinutes                        genres  averageRating  numVotes  \
# 0              1          [Documentary, Short]            5.7      2133
# 1              5  [Animation, Comedy, Romance]            6.4      2167
# 2              1                [Short, Sport]            5.3       900
# 3              1          [Documentary, Short]            5.4      2278
# 4              1          [Documentary, Short]            6.8      7865
# 5              1          [Documentary, Short]            7.4     13361
# 6              1          [Documentary, Short]            5.7      2047
# 7              1               [Comedy, Short]            7.1      6094
# 8              2            [Animation, Short]            6.1      1258
# 9              1          [Documentary, Short]            5.9      1645
#
#                 directors writers  ... archive_sound casting_director  \
# 0             [nm0005690]    [\N]  ...            []               []
# 1             [nm0721526]    [\N]  ...            []               []
# 2  [nm0005690, nm0374658]    [\N]  ...            []               []
# 3             [nm0005690]    [\N]  ...            []               []
# 4             [nm0525910]    [\N]  ...            []               []
# 5  [nm0525908, nm0525910]    [\N]  ...            []               []
# 6             [nm0525910]    [\N]  ...            []               []
# 7             [nm0525910]    [\N]  ...            []               []
# 8             [nm0721526]    [\N]  ...            []               []
# 9             [nm0525910]    [\N]  ...            []               []
#
#   cinematographer     composer                director       editor  \
# 0     [nm0374658]           []             [nm0005690]           []
# 1              []  [nm1335271]             [nm0721526]  [nm5442200]
# 2     [nm0374658]           []  [nm0005690, nm0374658]           []
# 3     [nm0374658]           []             [nm0005690]           []
# 4     [nm0525910]           []             [nm0525910]           []
# 5     [nm0525910]           []  [nm0525908, nm0525910]           []
# 6     [nm0525910]           []             [nm0525910]           []
# 7     [nm0525910]           []             [nm0525910]           []
# 8              []           []             [nm0721526]           []
# 9     [nm0525910]           []             [nm0525910]           []
#
#                  producer production_designer  \
# 0             [nm0005690]                  []
# 1  [nm1770680, nm0721526]                  []
# 2  [nm0005690, nm0249379]                  []
# 3             [nm0005690]                  []
# 4             [nm0525910]                  []
# 5  [nm0525908, nm0525910]                  []
# 6             [nm0525910]                  []
# 7             [nm0525910]                  []
# 8                      []                  []
# 9             [nm0525910]                  []
#
#                                                 self writer
# 0                                        [nm1588970]     []
# 1                                                 []     []
# 2                                                 []     []
# 3                                                 []     []
# 4                                                 []     []
# 5  [nm2880396, nm9735580, nm0525900, nm9735581, n...     []
# 6                             [nm0525908, nm1715062]     []
# 7                                                 []     []
# 8                                                 []     []
# 9                             [nm0525900, nm9735581]     []
#
# [10 rows x 23 columns]

# %% [markdown]
# ##### Create User Table

# %% [markdown]
# ### Newest One

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

def create_enhanced_user_profiles(ratings_df, movie_features):
    """
    Create user profiles by rating buckets, with summary statistics from `movie_features`.
    Includes:
      - Basic numeric stats (year/runtime/rating/etc.)
      - Proportion of genres
      - Top directors/writers lists
    """
    # --------------------------------------------------------------------------
    # 1. Copy dataframes to avoid modifying the originals
    # --------------------------------------------------------------------------
    movie_features = movie_features.copy()
    ratings_df = ratings_df.copy()
    
    # --------------------------------------------------------------------------
    # 2. Preprocess movie_features: remove 'tt' prefix, convert numeric columns
    # --------------------------------------------------------------------------
    movie_features['numeric_tconst'] = (
        movie_features['tconst']
        .str.replace('tt', '', regex=False)
        .astype(float)
    )

    movie_features['startYear'] = pd.to_numeric(movie_features['startYear'], errors='coerce')
    movie_features['runtimeMinutes'] = pd.to_numeric(movie_features['runtimeMinutes'], errors='coerce')

    # --------------------------------------------------------------------------
    # 3. Helper function to gather bucket-level stats
    # --------------------------------------------------------------------------
    def get_bucket_stats(movies_df):
        """Given a subset of movie_features, return relevant statistics."""
        if len(movies_df) == 0:
            return {}
        
        stats = {}
        # A. Basic movie IDs and count
        stats['movie_ids'] = list(movies_df['tconst'])
        stats['count'] = len(movies_df)
        
        # B. Numeric features
        numeric_features = {
            'adult_prop': 'isAdult',
            'year_avg': 'startYear',
            'year_var': 'startYear',
            'runtime_avg': 'runtimeMinutes',
            'runtime_var': 'runtimeMinutes',
            'rating_avg': 'averageRating',
            'rating_var': 'averageRating',
            'numvotes_avg': 'numVotes',
            'numvotes_var': 'numVotes'
        }
        
        for stat_name, column in numeric_features.items():
            if column not in movies_df.columns:
                continue
            if 'avg' in stat_name:
                stats[stat_name] = movies_df[column].mean(skipna=True)
            elif 'var' in stat_name:
                stats[stat_name] = movies_df[column].var(skipna=True)
            elif 'prop' in stat_name:
                # For 'adult_prop', store the fraction that are adult
                # (assuming isAdult is 0 or 1).
                stats[stat_name] = movies_df[column].mean(skipna=True)
        
        # C. Genre proportions
        #    Assuming 'genres' is already a list of genres for each movie
        all_genres = []
        for genre_list in movies_df['genres']:
            if isinstance(genre_list, list):
                # Filter out "\N" or empty strings
                valid_genres = [g.strip() for g in genre_list if g and g != '\\N']
                all_genres.extend(valid_genres)
        
        if all_genres:
            genre_counts = pd.Series(all_genres).value_counts()
            genre_proportions = genre_counts / genre_counts.sum()
            # Store as a dict: {genre: proportion}
            stats['genre_proportions'] = dict(genre_proportions)
        
        # D. Directors and Writers
        #    We'll store top 3 for each, but you can expand as needed.
        
        # Directors
        all_directors = []
        for directors_list in movies_df['directors']:
            if isinstance(directors_list, list):
                valid_directors = [d.strip() for d in directors_list if d and d != '\\N']
                all_directors.extend(valid_directors)
        
        if all_directors:
            director_counts = pd.Series(all_directors).value_counts()
            stats['top_directors'] = list(director_counts.head(3).index)
        
        # Writers
        all_writers = []
        for writers_list in movies_df['writers']:
            if isinstance(writers_list, list):
                valid_writers = [w.strip() for w in writers_list if w and w != '\\N']
                all_writers.extend(valid_writers)
        
        if all_writers:
            writer_counts = pd.Series(all_writers).value_counts()
            stats['top_writers'] = list(writer_counts.head(3).index)
        
        return stats

    # --------------------------------------------------------------------------
    # 4. Main user-profile creation
    # --------------------------------------------------------------------------
    user_profiles = []
    
    # Define your rating buckets
    buckets = [(0, 2), (3, 4), (5, 6), (7, 8), (9, 10)]
    
    unique_users = ratings_df['userId'].unique()
    pbar = tqdm(unique_users, desc="Creating user profiles")

    for user_id in pbar:
        user_ratings = ratings_df[ratings_df['userId'] == user_id]
        total_ratings = len(user_ratings)
        
        # Basic info about the user's rating behavior
        profile = {
            'userId': user_id,
            'total_ratings': total_ratings,
            'rating_avg': user_ratings['rating'].mean(),
            'rating_std': user_ratings['rating'].std(),
            'rating_proportions': dict(user_ratings['rating'].value_counts(normalize=True))
        }
        
        # Store references for bucket stats
        bucket_counts = {}
        bucket_stats_dict = {}
        
        # Process each rating bucket
        for low, high in buckets:
            bucket_name = f'bucket_{low}_{high}'
            bucket_ratings = user_ratings[
                (user_ratings['rating'] >= low) & (user_ratings['rating'] <= high)
            ]
            
            # Find the movies in this bucket
            bucket_movies = movie_features[
                movie_features['numeric_tconst'].isin(bucket_ratings['imdbId'])
            ]
            
            # Gather stats
            bucket_stats = get_bucket_stats(bucket_movies)
            bucket_counts[bucket_name] = bucket_stats.get('count', 0)
            bucket_stats_dict[bucket_name] = bucket_stats
            
            # Add each stat to the user profile with a prefix
            for stat_name, stat_value in bucket_stats.items():
                profile[f'{bucket_name}_{stat_name}'] = stat_value
        
        # ----------------------------------------------------------------------
        # 5. Interaction features (ratios, differences, etc.) between buckets
        # ----------------------------------------------------------------------
        for i, (low1, high1) in enumerate(buckets):
            for j, (low2, high2) in enumerate(buckets[i+1:], i+1):
                bucket1_name = f'bucket_{low1}_{high1}'
                bucket2_name = f'bucket_{low2}_{high2}'

                # Ratio of counts
                ratio_name = f'ratio_{bucket1_name}_to_{bucket2_name}'
                denom = bucket_counts[bucket2_name]
                profile[ratio_name] = (
                    bucket_counts[bucket1_name] / denom if denom > 0 else 0
                )

                # Differences of average stats (year/runtime/rating)
                for stat in ['year_avg', 'runtime_avg', 'rating_avg']:
                    if (bucket_stats_dict[bucket1_name].get(stat) is not None and
                        bucket_stats_dict[bucket2_name].get(stat) is not None):
                        diff_name = f'{stat}_diff_{bucket1_name}_vs_{bucket2_name}'
                        profile[diff_name] = (
                            bucket_stats_dict[bucket1_name][stat] -
                            bucket_stats_dict[bucket2_name][stat]
                        )
        
        # Another example: ratio of high-ratings to low-ratings
        high_count = bucket_counts.get('bucket_7_8', 0) + bucket_counts.get('bucket_9_10', 0)
        low_count = (
            bucket_counts.get('bucket_0_2', 0) +
            bucket_counts.get('bucket_3_4', 0) +
            1e-6  # avoid zero-division
        )
        profile['high_vs_low_ratio'] = high_count / low_count
        
        # ----------------------------------------------------------------------
        # 6. Overall stats for all movies the user rated
        # ----------------------------------------------------------------------
        all_movies = movie_features[
            movie_features['numeric_tconst'].isin(user_ratings['imdbId'])
        ]
        overall_stats = get_bucket_stats(all_movies)
        for k, v in overall_stats.items():
            profile[f'overall_{k}'] = v
        
        user_profiles.append(profile)

    pbar.close()
    
    # Convert list of dicts into a DataFrame
    return pd.DataFrame(user_profiles)

# ---------------------------------------------------------------------
# Example Usage in a Notebook (after you define `combined` and `movie_features`)
# ---------------------------------------------------------------------
enhanced_user_profiles2 = create_enhanced_user_profiles(combined, movie_features)
display(enhanced_user_profiles2.head())
# Out:
# Creating user profiles: 100%|██████████| 200948/200948 [1:55:44<00:00, 28.93it/s]
#    userId  total_ratings  rating_avg  rating_std  \
# 0       1            141    3.531915    1.537870
# 1       2             52    4.269231    1.122242
# 2       3            147    3.588435    1.014789
# 3       4             27    2.629630    1.043225
# 4       5             33    3.272727    0.910794
#
#                                   rating_proportions  \
# 0  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 1  {5.0: 0.5961538461538461, 4.0: 0.2115384615384...
# 2  {4.0: 0.43537414965986393, 3.0: 0.183673469387...
# 3  {2.0: 0.4074074074074074, 3.0: 0.2592592592592...
# 4  {3.0: 0.48484848484848486, 4.0: 0.333333333333...
#
#                                 bucket_0_2_movie_ids  bucket_0_2_count  \
# 0  [tt0034583, tt0045793, tt0056172, tt0059113, t...              39.0
# 1       [tt0109040, tt0109686, tt0110148, tt0110912]               4.0
# 2  [tt0054033, tt0060782, tt0088161, tt0102216, t...              12.0
# 3  [tt0097162, tt0099052, tt0120032, tt0120657, t...              14.0
# 4       [tt0109686, tt0110148, tt0110912, tt0111161]               4.0
#
#    bucket_0_2_adult_prop  bucket_0_2_year_avg  bucket_0_2_year_var  ...  \
# 0                    0.0          1988.153846           171.923077  ...
# 1                    0.0          1994.000000             0.000000  ...
# 2                    0.0          1988.666667           162.787879  ...
# 3                    0.0          1997.428571            11.648352  ...
# 4                    0.0          1994.000000             0.000000  ...
#
#    overall_year_var  overall_runtime_avg  overall_runtime_var  \
# 0        221.714083           122.609929           725.596758
# 1         73.923077           110.673077           391.792986
# 2        117.339111           119.258503           591.987513
# 3         60.028490           109.000000           372.461538
# 4          2.354167           124.636364           539.238636
#
#    overall_rating_avg  overall_rating_var  overall_numvotes_avg  \
# 0            7.678014            0.397442         316521.531915
# 1            6.942308            0.772293         344699.653846
# 2            7.182313            0.706534         405335.149660
# 3            6.744444            0.381795         170791.259259
# 4            7.466667            0.799792         638410.060606
#
#   overall_numvotes_var                          overall_genre_proportions  \
# 0         1.811400e+11  {'Drama': 0.3125, 'Comedy': 0.1477272727272727...
# 1         3.543127e+11  {'Drama': 0.2396694214876033, 'Comedy': 0.1900...
# 2         2.439600e+11  {'Adventure': 0.1649746192893401, 'Action': 0....
# 3         4.959259e+10  {'Action': 0.14285714285714285, 'Horror': 0.11...
# 4         5.806468e+11  {'Drama': 0.19540229885057472, 'Action': 0.172...
#
#                overall_top_directors                overall_top_writers
# 0  [nm0001661, nm0000229, nm0000416]  [nm0001410, nm0000184, nm0000416]
# 1  [nm0001060, nm0936374, nm0001708]  [nm0560329, nm0322368, nm0363125]
# 2  [nm0000709, nm0000229, nm0378893]  [nm0363125, nm0560329, nm0462895]
# 3  [nm0001532, nm0769874, nm0882330]  [nm0000184, nm0371249, nm0000338]
# 4  [nm0000318, nm0591450, nm0000233]  [nm0761498, nm0560329, nm0363125]
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Start Normalizing Data

# %%
enhanced_user_profiles2.to_csv("./Datasets/enhanced_user_profiles2.csv", index=False)

# %%
len(enhanced_user_profiles2)
# Out:
# 200948

# %%
def normalize_user_profiles(df):
    """
    Normalize the enhanced user profiles dataframe
    """
    df = df.copy()
    
    # 1. Skip ID columns and list/dictionary columns (no normalization needed)
    skip_columns = [
        'userId',
        'rating_proportions',
        *[col for col in df.columns if 'movie_ids' in col],
        *[col for col in df.columns if 'genre_proportions' in col],
        *[col for col in df.columns if 'top_directors' in col],
        *[col for col in df.columns if 'top_writers' in col]
    ]
    
    # 2. Min-Max scaling for proportions and ratios (already between 0-1 or meaningful ratios)
    ratio_columns = [col for col in df.columns if 'ratio' in col or 'prop' in col]
    
    # 3. Standard scaling for counts, averages, and variances
    from sklearn.preprocessing import StandardScaler
    
    # Get numeric columns that aren't in skip_columns or ratio_columns
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    scale_columns = [col for col in numeric_columns 
                    if col not in skip_columns 
                    and col not in ratio_columns]
    
    # Apply standard scaling
    scaler = StandardScaler()
    df[scale_columns] = scaler.fit_transform(df[scale_columns])
    
    # 4. Handle any missing values
    # For numeric columns, fill with 0 (representing average after scaling)
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)
    
    # For list/dict columns, fill with empty lists/dicts
    for col in skip_columns:
        if col in df.columns:
            if 'proportions' in col:
                df[col] = df[col].fillna({})
            elif any(x in col for x in ['movie_ids', 'top_directors', 'top_writers']):
                df[col] = df[col].fillna([])
    
    return df

# Usage:
normalized_profiles = normalize_user_profiles(enhanced_user_profiles)

# %%
###

# %% [markdown]
# ### New One

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

def create_enhanced_user_profiles(ratings_df, movie_features):
    """
    Create user profiles by rating buckets, with summary statistics from `movie_features`.
    """
    movie_features = movie_features.copy()
    ratings_df = ratings_df.copy()
    
    # Remove 'tt' prefix and convert to numeric for tconst
    movie_features['numeric_tconst'] = (
        movie_features['tconst']
        .str.replace('tt', '', regex=False)
        .astype(float)
    )
    
    # Convert to numeric columns
    movie_features['startYear'] = pd.to_numeric(movie_features['startYear'], errors='coerce')
    movie_features['runtimeMinutes'] = pd.to_numeric(movie_features['runtimeMinutes'], errors='coerce')
    
    def get_bucket_stats(movies_df):
        """Given a subset of movie_features, return relevant statistics."""
        if len(movies_df) == 0:
            return {}
        
        stats = {}
        stats['movie_ids'] = list(movies_df['tconst'])
        stats['count'] = len(movies_df)
        
        numeric_features = {
            'adult_prop': 'isAdult',
            'year_avg': 'startYear',
            'year_var': 'startYear',
            'runtime_avg': 'runtimeMinutes',
            'runtime_var': 'runtimeMinutes',
            'rating_avg': 'averageRating',
            'rating_var': 'averageRating',
            'numvotes_avg': 'numVotes',
            'numvotes_var': 'numVotes'
        }
        
        for stat_name, column in numeric_features.items():
            if column not in movies_df.columns:
                continue
            if 'avg' in stat_name:
                stats[stat_name] = movies_df[column].mean(skipna=True)
            elif 'var' in stat_name:
                stats[stat_name] = movies_df[column].var(skipna=True)
        
        return stats
    
    user_profiles = []
    buckets = [(0, 2), (3, 4), (5, 6), (7, 8), (9, 10)]
    
    unique_users = ratings_df['userId'].unique()
    pbar = tqdm(unique_users, desc="Creating user profiles")
    
    for user_id in pbar:
        user_ratings = ratings_df[ratings_df['userId'] == user_id]
        total_ratings = len(user_ratings)
        
        profile = {
            'userId': user_id,
            'total_ratings': total_ratings,
            'rating_avg': user_ratings['rating'].mean(),
            'rating_std': user_ratings['rating'].std(),
            'rating_proportions': dict(user_ratings['rating'].value_counts(normalize=True))
        }
        
        bucket_counts = {}
        bucket_stats_dict = {}
        
        for low, high in buckets:
            bucket_ratings = user_ratings[(user_ratings['rating'] >= low) & (user_ratings['rating'] <= high)]
            bucket_movies = movie_features[movie_features['numeric_tconst'].isin(bucket_ratings['imdbId'])]
            bucket_stats = get_bucket_stats(bucket_movies)
            bucket_name = f'bucket_{low}_{high}'
            
            bucket_counts[bucket_name] = bucket_stats.get('count', 0)
            bucket_stats_dict[bucket_name] = bucket_stats
            
            for stat_name, stat_value in bucket_stats.items():
                profile[f'{bucket_name}_{stat_name}'] = stat_value
        
        for i, (low1, high1) in enumerate(buckets):
            for j, (low2, high2) in enumerate(buckets[i+1:], i+1):
                bucket1_name = f'bucket_{low1}_{high1}'
                bucket2_name = f'bucket_{low2}_{high2}'
                
                ratio_name = f'ratio_{bucket1_name}_to_{bucket2_name}'
                denom = bucket_counts[bucket2_name]
                profile[ratio_name] = (
                    bucket_counts[bucket1_name] / denom if denom > 0 else 0
                )
                
                for stat in ['year_avg', 'runtime_avg', 'rating_avg']:
                    if (bucket_stats_dict[bucket1_name].get(stat) is not None and
                        bucket_stats_dict[bucket2_name].get(stat) is not None):
                        diff_name = f'{stat}_diff_{bucket1_name}_vs_{bucket2_name}'
                        profile[diff_name] = (
                            bucket_stats_dict[bucket1_name][stat] -
                            bucket_stats_dict[bucket2_name][stat]
                        )
        
        high_count = bucket_counts.get('bucket_7_8', 0) + bucket_counts.get('bucket_9_10', 0)
        low_count = (bucket_counts.get('bucket_0_2', 0) +
                     bucket_counts.get('bucket_3_4', 0) +
                     1e-6)
        profile['high_vs_low_ratio'] = high_count / low_count
        
        all_movies = movie_features[movie_features['numeric_tconst'].isin(user_ratings['imdbId'])]
        overall_stats = get_bucket_stats(all_movies)
        
        for k, v in overall_stats.items():
            profile[f'overall_{k}'] = v
        
        user_profiles.append(profile)
    
    pbar.close()
    return pd.DataFrame(user_profiles)

# Example Usage in Jupyter Notebook:
# Assuming `combined` is your ratings_df, and `movie_features` is your DataFrame with tconst and additional data.
# Run this cell after defining `combined` and `movie_features`.

enhanced_user_profiles = create_enhanced_user_profiles(combined, movie_features)
display(enhanced_user_profiles.head())
# Out:
# Creating user profiles: 100%|██████████| 200948/200948 [51:47<00:00, 64.67it/s]
#    userId  total_ratings  rating_avg  rating_std  \
# 0       1            141    3.531915    1.537870
# 1       2             52    4.269231    1.122242
# 2       3            147    3.588435    1.014789
# 3       4             27    2.629630    1.043225
# 4       5             33    3.272727    0.910794
#
#                                   rating_proportions  \
# 0  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 1  {5.0: 0.5961538461538461, 4.0: 0.2115384615384...
# 2  {4.0: 0.43537414965986393, 3.0: 0.183673469387...
# 3  {2.0: 0.4074074074074074, 3.0: 0.2592592592592...
# 4  {3.0: 0.48484848484848486, 4.0: 0.333333333333...
#
#                                 bucket_0_2_movie_ids  bucket_0_2_count  \
# 0  [tt0034583, tt0045793, tt0056172, tt0059113, t...              39.0
# 1       [tt0109040, tt0109686, tt0110148, tt0110912]               4.0
# 2  [tt0054033, tt0060782, tt0088161, tt0102216, t...              12.0
# 3  [tt0097162, tt0099052, tt0120032, tt0120657, t...              14.0
# 4       [tt0109686, tt0110148, tt0110912, tt0111161]               4.0
#
#    bucket_0_2_year_avg  bucket_0_2_year_var  bucket_0_2_runtime_avg  ...  \
# 0          1988.153846           171.923077              123.128205  ...
# 1          1994.000000             0.000000              117.500000  ...
# 2          1988.666667           162.787879              100.833333  ...
# 3          1997.428571            11.648352              103.857143  ...
# 4          1994.000000             0.000000              131.500000  ...
#
#                                    overall_movie_ids  overall_count  \
# 0  [tt0032143, tt0033467, tt0034583, tt0036868, t...            141
# 1  [tt0029583, tt0065421, tt0096895, tt0099653, t...             52
# 2  [tt0032910, tt0038650, tt0049833, tt0054033, t...            147
# 3  [tt0066206, tt0078767, tt0086190, tt0087469, t...             27
# 4  [tt0096895, tt0099348, tt0101414, tt0102926, t...             33
#
#    overall_year_avg  overall_year_var  overall_runtime_avg  \
# 0       1984.652482        221.714083           122.609929
# 1       1992.192308         73.923077           110.673077
# 2       1991.408163        117.339111           119.258503
# 3       1994.518519         60.028490           109.000000
# 4       1993.666667          2.354167           124.636364
#
#   overall_runtime_var  overall_rating_avg  overall_rating_var  \
# 0          725.596758            7.678014            0.397442
# 1          391.792986            6.942308            0.772293
# 2          591.987513            7.182313            0.706534
# 3          372.461538            6.744444            0.381795
# 4          539.238636            7.466667            0.799792
#
#    overall_numvotes_avg  overall_numvotes_var
# 0         316521.531915          1.811400e+11
# 1         344699.653846          3.543127e+11
# 2         405335.149660          2.439600e+11
# 3         170791.259259          4.959259e+10
# 4         638410.060606          5.806468e+11
#
# [5 rows x 65 columns]

# %%
movie_features.columns
# Out:
# Index(['tconst', 'primaryTitle', 'isAdult', 'startYear', 'runtimeMinutes',
#        'genres', 'averageRating', 'numVotes', 'directors', 'writers', 'actor',
#        'actress', 'archive_footage', 'archive_sound', 'casting_director',
#        'cinematographer', 'composer', 'director', 'editor', 'producer',
#        'production_designer', 'self', 'writer'],
#       dtype='object')

# %%
enhanced_user_profiles.columns
# Out:
# Index(['userId', 'total_ratings', 'rating_avg', 'rating_std',
#        'rating_proportions', 'bucket_0_2_movie_ids', 'bucket_0_2_count',
#        'bucket_0_2_year_avg', 'bucket_0_2_year_var', 'bucket_0_2_runtime_avg',
#        'bucket_0_2_runtime_var', 'bucket_0_2_rating_avg',
#        'bucket_0_2_rating_var', 'bucket_0_2_numvotes_avg',
#        'bucket_0_2_numvotes_var', 'bucket_3_4_movie_ids', 'bucket_3_4_count',
#        'bucket_3_4_year_avg', 'bucket_3_4_year_var', 'bucket_3_4_runtime_avg',
#        'bucket_3_4_runtime_var', 'bucket_3_4_rating_avg',
#        'bucket_3_4_rating_var', 'bucket_3_4_numvotes_avg',
#        'bucket_3_4_numvotes_var', 'bucket_5_6_movie_ids', 'bucket_5_6_count',
#        'bucket_5_6_year_avg', 'bucket_5_6_year_var', 'bucket_5_6_runtime_avg',
#        'bucket_5_6_runtime_var', 'bucket_5_6_rating_avg',
#        'bucket_5_6_rating_var', 'bucket_5_6_numvotes_avg',
#        'bucket_5_6_numvotes_var', 'ratio_bucket_0_2_to_bucket_3_4',
#        'year_avg_diff_bucket_0_2_vs_bucket_3_4',
#        'runtime_avg_diff_bucket_0_2_vs_bucket_3_4',
#        'rating_avg_diff_bucket_0_2_vs_bucket_3_4',
#        'ratio_bucket_0_2_to_bucket_5_6',
#        'year_avg_diff_bucket_0_2_vs_bucket_5_6',
#        'runtime_avg_diff_bucket_0_2_vs_bucket_5_6',
#        'rating_avg_diff_bucket_0_2_vs_bucket_5_6',
#        'ratio_bucket_0_2_to_bucket_7_8', 'ratio_bucket_0_2_to_bucket_9_10',
#        'ratio_bucket_3_4_to_bucket_5_6',
#        'year_avg_diff_bucket_3_4_vs_bucket_5_6',
#        'runtime_avg_diff_bucket_3_4_vs_bucket_5_6',
#        'rating_avg_diff_bucket_3_4_vs_bucket_5_6',
#        'ratio_bucket_3_4_to_bucket_7_8', 'ratio_bucket_3_4_to_bucket_9_10',
#        'ratio_bucket_5_6_to_bucket_7_8', 'ratio_bucket_5_6_to_bucket_9_10',
#        'ratio_bucket_7_8_to_bucket_9_10', 'high_vs_low_ratio',
#        'overall_movie_ids', 'overall_count', 'overall_year_avg',
#        'overall_year_var', 'overall_runtime_avg', 'overall_runtime_var',
#        'overall_rating_avg', 'overall_rating_var', 'overall_numvotes_avg',
#        'overall_numvotes_var'],
#       dtype='object')

# %%
len(enhanced_user_profiles)
# Out:
# 200948

# %%
def create_combined_features_table(ratings_df, user_profiles_df, movie_features_df):
    print("Starting to create combined features table...")
    
    # First merge ratings with user profiles
    print("Merging ratings with user profiles...")
    combined_df = ratings_df.merge(
        user_profiles_df,
        on='userId',
        how='left'
    )
    
    # Then merge with movie features
    # Convert imdbId to string to match tconst format in movie_features
    print("Merging with movie features...")
    combined_df['imdbId'] = combined_df['imdbId'].astype(str)
    combined_df = combined_df.merge(
        movie_features_df,
        left_on='imdbId',
        right_on='tconst',
        how='left'
    )
    
    # Drop any duplicate columns
    # Keep track of columns we want to keep
    cols_to_keep = (
        ['userId', 'movieId', 'rating', 'timestamp', 'imdbId'] +
        [col for col in user_profiles_df.columns if col != 'userId'] +
        [col for col in movie_features_df.columns if col != 'tconst']
    )
    
    combined_df = combined_df[cols_to_keep]
    
    print(f"\nFinal combined table shape: {combined_df.shape}")
    print(f"Number of unique users: {combined_df['userId'].nunique()}")
    print(f"Number of unique movies: {combined_df['movieId'].nunique()}")
    
    return combined_df

# Create the combined table
combined_features = create_combined_features_table(
    ratings_df=combined,  # Your original ratings dataframe
    user_profiles_df=enhanced_user_profiles,
    movie_features_df=movie_features
)

# Display sample of the combined table
print("\nSample of combined features table:")
print(combined_features.head())

# Display column info
print("\nColumn information:")
print(combined_features.info())
# Out:
# Starting to create combined features table...
# Merging ratings with user profiles...
# Merging with movie features...
#
# Final combined table shape: (31972560, 52)
# Number of unique users: 200948
# Number of unique movies: 83955
#
# Sample of combined features table:
#    userId  movieId  rating  timestamp  imdbId  total_ratings  rating_avg  \
# 0       1       17     4.0  944249077  114388            141    3.531915
# 1       1       25     1.0  944250228  113627            141    3.531915
# 2       1       29     2.0  943230976  112682            141    3.531915
# 3       1       30     5.0  944249077  115012            141    3.531915
# 4       1       32     5.0  943228858  114746            141    3.531915
#
#    rating_std                                 rating_proportions  \
# 0     1.53787  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 1     1.53787  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 2     1.53787  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 3     1.53787  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
# 4     1.53787  {5.0: 0.40425531914893614, 4.0: 0.184397163120...
#
#    bucket_0_2_count  ...  archive_sound  casting_director  cinematographer  \
# 0                 0  ...            NaN               NaN              NaN
# 1                 0  ...            NaN               NaN              NaN
# 2                 0  ...            NaN               NaN              NaN
# 3                 0  ...            NaN               NaN              NaN
# 4                 0  ...            NaN               NaN              NaN
#
#    composer  director  editor  producer  production_designer  self  writer
# 0       NaN       NaN     NaN       NaN                  NaN   NaN     NaN
# 1       NaN       NaN     NaN       NaN                  NaN   NaN     NaN
# 2       NaN       NaN     NaN       NaN                  NaN   NaN     NaN
# 3       NaN       NaN     NaN       NaN                  NaN   NaN     NaN
# 4       NaN       NaN     NaN       NaN                  NaN   NaN     NaN
#
# [5 rows x 52 columns]
#
# Column information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31972560 entries, 0 to 31972559
# Data columns (total 52 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   userId                           int64
#  1   movieId                          int64
#  2   rating                           float64
#  3   timestamp                        int64
#  4   imdbId                           object
#  5   total_ratings                    int64
#  6   rating_avg                       float64
#  7   rating_std                       float64
#  8   rating_proportions               object
#  9   bucket_0_2_count                 int64
#  10  bucket_0_2_proportion            float64
#  11  bucket_3_4_count                 int64
#  12  bucket_3_4_proportion            float64
#  13  bucket_5_6_count                 int64
#  14  bucket_5_6_proportion            float64
#  15  bucket_7_8_count                 int64
#  16  bucket_7_8_proportion            float64
#  17  bucket_9_10_count                int64
#  18  bucket_9_10_proportion           float64
#  19  ratio_bucket_0_2_to_bucket_3_4   int64
#  20  ratio_bucket_0_2_to_bucket_5_6   int64
#  21  ratio_bucket_0_2_to_bucket_7_8   int64
#  22  ratio_bucket_0_2_to_bucket_9_10  int64
#  23  ratio_bucket_3_4_to_bucket_5_6   int64
#  24  ratio_bucket_3_4_to_bucket_7_8   int64
#  25  ratio_bucket_3_4_to_bucket_9_10  int64
#  26  ratio_bucket_5_6_to_bucket_7_8   int64
#  27  ratio_bucket_5_6_to_bucket_9_10  int64
#  28  ratio_bucket_7_8_to_bucket_9_10  int64
#  29  high_vs_low_ratio                float64
#  30  primaryTitle                     object
#  31  isAdult                          float64
#  32  startYear                        object
#  33  runtimeMinutes                   object
#  34  genres                           object
#  35  averageRating                    float64
#  36  numVotes                         float64
#  37  directors                        object
#  38  writers                          object
#  39  actor                            object
#  40  actress                          object
#  41  archive_footage                  object
#  42  archive_sound                    object
#  43  casting_director                 object
#  44  cinematographer                  object
#  45  composer                         object
#  46  director                         object
#  47  editor                           object
#  48  producer                         object
#  49  production_designer              object
#  50  self                             object
#  51  writer                           object
# dtypes: float64(12), int64(19), object(21)
# memory usage: 12.4+ GB
# None

# %%
# Save the combined features table to CSV
output_path = "./Datasets/combined_features.csv"
combined_features.to_csv(output_path, index=False)
print(f"Combined features table saved to: {output_path}")
# Out:
# Combined features table saved to: ./Datasets/combined_features.csv

# %% [markdown]
# ### Remove Redundant Information. MovieID IMDBId
# ### Focus on director and writer remove the rest
# ### For Missing Values Add Averages.
# ### Convert Genres Into Binary Features

# %%
### Divide into 5 buckets 
### Movies rated from [0,2] [3,4][5,6][7,8][9,10]
### For each bucket 
### Movie ID's of movies in the bucket
### Adult movie proportion
### startYear Average
### StartYear Variance
### Runtime Average
### Runtime Variance
### Genres Proportions
### List of Directors for movies
### List of writers for movies
### Average Numvotes
### Variance Numvotes


### User Information
    ### Average Rating 
    ### Rating Deviation

# %%
### Both Liked and Watched
    ### Adult Proportions
    ### StartYear Average 
    ### StartYear Variance
    ### Runtime Average
    ### Runtime Variance
    ### Genres Proportions
    ### Directors  
    ### Writers
    ### Average Rating 
    ### Variance Rating 
    ### Average NumVotes
    ### Variance Numvotes 

### User Information
    ### Average Rating 
    ### Rating Deviation   
    ### Proportion of Rating
